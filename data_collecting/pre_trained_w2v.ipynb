# %%
from gensim.models import FastText

file_name = r"C:\Users\jym97\Desktop\cc.ko.300.bin.gz"
model = FastText.load_fasttext_format(file_name)

# %%
li = model.most_similar('여성', topn=4000)
for w, v in li:
    print(w)

# %%
w_list1 = ["女", "여선생", '여사친', '독신녀', '흑인녀', '업소녀', '계집', '식모', '색녀', 
          '레즈비언', '딸', '아줌마', 
          '여인', '할망구', '엄마', '김치년', '처자', '여아', '가출소녀', '흔녀', '여탕', 
          '부녀', '미인', '여대', '노파', 
          '서양녀', '숫처녀', '건어물녀', '차도녀', '여친', '여후배', '여학생', '숙녀', '손녀', 
          '여교수', '처녀', '보모', 
          '여고딩', '선녀', '미녀', '여배우', '여군', '그녀', '쌍년', '썸녀', '스시녀', '언니', 
          '여고', '클럽녀', '여교사', 
          '여의사', '딸내미', '여대생', '여직원', '내연녀', '싱글녀', '여선배', '누나', '연상녀', 
          '여캐', '이혼녀', '자매', 
          '일진녀', '여초', '신상녀', '여고생', '섹녀', '숙녀', '순정녀', '여왕', '브레지어', 
          '여경', '여고부', '아내', 
          '기지배', '창녀', '효녀', 'A양', '폐경', '콜걸', '훈녀', '맘충', '작업녀', '화녀', '여인'
          , '여신', 'L양', '과부', 
          '아내', '일본녀', '처자들', '여사장님', '모녀', '모계', '할례', '중년여인', '여주인인', 
          '노처녀', '알파걸', 
          '자위녀', '母', '여스승', '여왕벌', '공주', '의붓딸', '왕비', '매력녀', '가임', '색녀', 
          '여군', '여권신장', 
          '흑인녀', '경단녀', '출산', '미녀', '산모', '여형사', '알파걸', '모계', '유리천장', 
          '여인', '갱년기', '낙태', 
          '싱글녀', '꽃뱀', '식모', '임신부', '경부암', '부인암', '여초', '여상사', '과부', '여사원',
          '모성', '매춘부', 
          '메갈', '빠순이', '여종업원', '여군', '난소', '여사친', '커버걸', '노브라', '히잡', 
          '뚱녀', '클리토리스', 
          '우먼스', '암캐', '디바', '여교수', '수녀', '여가부', 'woman', 'women', '장모', '업소녀',
          '월경', '임산부', 
          '자궁', '싱글맘', '영부인', '페미', '여기자', '탐폰', '생리대', '커리우먼', '워마드', 
          '여중생', '여군', 
          '여신도', '걸즈', '이혼녀', '미혼모', '성녀', '여가수', '유모', '서양녀', '독신녀', 
          '퀸카', '맞선녀', '썸녀', 
          '색녀', '업소녀', '새댁', '연상녀', '여아', '만찢녀', '작업녀', '건어물녀', '돌싱녀', 
          '여캐', '여고부', '여제', 
          '클럽녀', '신상녀', '쌍년', '차도녀']

# %%
w_list2 = list(set(w_list1))

# %%
print(len(w_list1), len(w_list2))
# Out:
# 197 162

# %%
print(w_list2)
# Out:
# ['창녀', '여고딩', '그녀', '쌍년', '계집', '엄마', '보모', '왕비', '임산부', '아내', '미녀', '여직원', '자위녀', '유모', '여선배', '여대생', '콜걸', '만찢녀', '가출소녀', '기지배', '섹녀', '경단녀', '독신녀', '훈녀', '모녀', '빠순이', 'A양', '미인', '클럽녀', '돌싱녀', '모계', '작업녀', 'L양', '새댁', '처녀', '여왕', '화녀', '숙녀', '여주인인', '과부', '모성', '퀸카', '여신', '순정녀', '산모', '히잡', '여형사', '여의사', '가임', '처자들', 'woman', '여사친', '여배우', '손녀', '여왕벌', '여가수', '난소', '싱글녀', '커버걸', '여중생', '폐경', '신상녀', '여탕', '영부인', '매춘부', '암캐', '언니', '공주', '딸내미', '여사장님', '갱년기', '탐폰', '선녀', '경부암', '커리우먼', '뚱녀', '할례', '여종업원', '김치년', '내연녀', '흔녀', '女', '식모', '여대', '부녀', '여고생', '여경', '일본녀', '레즈비언', '건어물녀', '매력녀', '여기자', '효녀', '여신도', '여친', '여제', '업소녀', '여캐', '여상사', '여사원', '의붓딸', '출산', '노처녀', '성녀', '맘충', '할망구', '우먼스', 'women', '여스승', '수녀', '자매', '여아', '여학생', '여선생', '딸', '클리토리스', '노브라', '일진녀', '디바', '여인', '알파걸', '여초', '연상녀', '자궁', '숫처녀', '브레지어', '색녀', '미혼모', '차도녀', '여고', '꽃뱀', '생리대', '낙태', '걸즈', '여군', '부인암', '노파', '여교수', '장모', '여가부', '이혼녀', '여고부', '母', '흑인녀', '메갈', '유리천장', '워마드', '여후배', '임신부', '페미', '아줌마', '
# ...

# %%
m_list1 = ['男', 'man', 'men', '노신사', '남친', '마마보이', '훈남', '이혼남', '까도남', '근육남', 
           '남배우', '남캐', '마초', '남직원', '미남', '할배', '작업남', '초식남', '중년남', '소심남', 
           '상남자', '쾌남', '추남', '인기남', '내연남', '남교사', '킹카', '소년', '유부남', '꽃남', 
           '남탕', '꽃미남', '오빠', '남학생', '사나이', '상남자', '재벌남', '연하남', '신사용', 
           '남편', '짐승남', '미남', '방귀남', '새신랑', '불륜남', '소년', '공익요원', '한남', '총각', 
           '매력남', '전남친', '멘즈', '맨즈', '옴므', '게이', '신사용', '남교사', '남배우', '초식남', 
           '호빠', '남친', '짐승돌', '독신남', '남캐', '전립선', '흔남', '남초', '유부남', '조루증', 
           '발기부전', '음경', '그루밍족', '유소년용', '테스토스테론', '근육남', '훈남', '상사맨', 
           '맨스', '여성혐오자', '틀딱충', 'BL', '군필자', '완소남', '보이즈', '가부장', '연하남', 
           '내연남', '가장들의', '삼촌팬']

# %%
m_list2 = list(set(m_list1))

# %%
print(len(m_list1), len(m_list2))
# Out:
# 89 75

# %%
print(m_list2)
# Out:
# ['유부남', '짐승남', '방귀남', '훈남', '남학생', '내연남', '신사용', '공익요원', 'men', '남배우', '남편', '흔남', '가부장', '남교사', '킹카', '남친', '한남', '짐승돌', '추남', '이혼남', '호빠', '매력남', '오빠', '불륜남', '독신남', '조루증', '총각', '테스토스테론', '상남자', '재벌남', '미남', '전남친', '멘즈', '작업남', '그루밍족', '꽃남', '남캐', '게이', '남초', '새신랑', '男', '소년', '틀딱충', '마초', '남탕', '완소남', '연하남', '유소년용', '전립선', '까도남', '맨즈', '쾌남', '맨스', '인기남', '마마보이', '남직원', '옴므', '할배', '발기부전', '여성혐오자', '근육남', 'BL', '보이즈', '가장들의', '소심남', '사나이', '음경', '삼촌팬', '상사맨', '중년남', '꽃미남', 'man', '군필자', '노신사', '초식남']
