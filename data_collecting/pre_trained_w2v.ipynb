# %%
import gensim
model = gensim.models.KeyedVectors.load_word2vec_format('cc.ko.300.vec', binary=False)

# %%
from gensim.models import FastText

file_name = r"C:\Users\jym97\Desktop\cc.ko.300.bin.gz"
model = FastText.load_fasttext_format(file_name)
# Out:
# C:\Users\jym97\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).
#   after removing the cwd from sys.path.

# %%
li = model.most_similar('남성', topn=4000)
for w, v in li:
    print(w)
# Out:
# C:\Users\jym97\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 여성
# 男性
# 南城
# 성별로는
# 女性
# 여성남성
# 기혼
# 메탈시계
# 숙녀들의
# 남녀
# 祝い酒
# 홀몬
# 멘즈
# 돔남성
# 싱글화이트
# 남성들
# 싱글18K
# 4중창단
# 인간분수
# 여성뿐
# 중년
# 싱글14K
# 남자
# 성인
# Z.N.E
# 남성에서
# 남성화
# 가임
# 남성과
# 여자
# 남성도
# 미혼
# 여성은
# 남성이다
# 남여
# 남성이
# 내의류
# 남성은
# 남성의
# 백인
# 미시옷
# 여성이
# 원룸서
# 맨즈
# -남성
# 레노마
# 여성중
# 시스젠더
# 연령층
# 가죽시계
# 성인남성
# 4중창
# 남성에게
# 중년층
# 여성을
# 남성에
# 비혼
# 아이돌부문
# 女
# 여성층에서
# 세레부
# 독신
# 미혼여성
# 女
# 가임기
# 초로의
# 우븐
# T-셔츠
# 女性
# 여성일
# 덧옷
# 여성인
# 여성보다는
# 2-30대
# 기성복
# 남성보다는
# 남성들의
# 갱년기는
# 남성뿐만
# 남성이나
# 타깃인
# 남성들이
# 보컬상
# 투척도
# 인명이며
# 남성을
# 여성부터
# 30대초반
# -여성
# 여성뿐만
# 성차
# 조선사극
# 만혼
# 十二単
# 브랜드품
# 성비
# 광고속의
# 한남패치
# 남성인
# 그루밍
# 브릿
# 청결제
# 옴므
# 정장화
# 윤락
# 흑인
# 듀오
# 젊은
# 연령별로는
# 남성만을
# 20-30대
# 남성보다
# 장년층
# 한국남성
# 남성화킨록앤더슨
# 쇼츠
# 男
# 보쿠
# 여성-
# 할례와
# 육아휴직자
# ...
