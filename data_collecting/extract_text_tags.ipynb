# %%
# 나중에 많이 짧은 뉴스는 생략하기. 
def html_extract(raw):
    from bs4 import BeautifulSoup
    import re
    import requests
    
    def replace_sub(text):
        
        text = text.replace("▶디지털 뉴스콘텐츠 이용규칙 보기", "").replace("저작권자 © 기호일보 무단전재 및 재배포 금지", "")
        text = text.replace(').push', '').replace('사진=연합뉴스', '').replace('/ TV조선 방송화면 캡처', '').replace('사진=뉴스1 제공', '')
        text = text.replace('사진출처: 온라인 커뮤니티', '').replace('/연합뉴스/', '').replace('▲ SBS <8뉴스> 화면 갈무리 ⓒ SBS', '')
        text = text.replace('< 경남신문의 콘텐츠는 저작권법의 보호를 받는 바, 무단전재·복사·재배포를 금합니다.', '').replace('ⓒ뉴시스', '')
        text = text.replace('기자의 다른 기사 보기', '').replace('◀ＥＮＤ▶', '')
        text = text.replace('독자와 공감을 통해 더 나은 내일을 만들겠습니다.', '')
        text = text.replace('여러분의 제보가 세상을 바꿀 수 있습니다. 세상을 건강하게 변화시키는 인사이트의 수많은 기사들은 여러분의 제보로부터 시작됩니다.', '')
        text = text.replace('당사의 허락없이 본 기사와 사진의 무단 전재 및 재배포를 금합니다.', '')
        text = text.replace('  저작권자 © 의협신문 무단전재 및 재배포 금지      편만섭 기자 다른기사 보기  ','')
        text = text.replace('<p>','')
        text = text.replace('<br>','')
        text = text.replace('<\p>','')
        text = text.replace('<\br>','')
        text = text.replace('사진=연합뉴스TV[헤럴드경제=모바일섹션]', '').replace('=', '').replace('사진제공연합뉴스', '')
        text = text.replace('동영상 뉴스', '').replace('사진연합뉴스', '').replace('/AP 연합뉴스', '')
        text = text.replace('사진제공', '').replace('ⓒ', '').replace('출처 AP 뉴시스', '').replace('©', '').replace('@', '')
        text = text.replace('삽화', '').replace('mtkhtyna.co.kr', '').replace('logosyna.co.kr', '').replace('changhani.co.kr', '')
        text = text.replace('ryousantayna.co.kr', '').replace('wooimaeil.com', '').replace('/뉴시스', '')
        text = text.replace('/퍼스퍼코리아', '').replace('/CICI', '').replace('kjh9326newsis.com', '').replace('제공|스포티비뉴스', '')
        text = text.replace('검찰 로고/뉴스1', '').replace('photonewsis.com', '').replace('photonewsis.com', '')
        text = text.replace('<<시각장애인 음성정보 지원을 위한 텍스트입니다>>', '').replace('/사진', '')
        text = text.replace('/뉴스1', '').replace('<저작권자 공감언론 뉴시스통신사. 무단전재-재배포 금지.>', '').replace('unsplash ', '')
        text = text.replace('kknphotokyunghyang.com', '').replace('SBS방송 캡처.', '').replace('사진게티이미지뱅크', '')
        text = text.replace('게티이미지 제공', '').replace('신한금융지주 제공', '').replace('사진pixabay', '').replace('ppkjmnewsis.com', '')
        text = text.replace('|연합뉴스', '').replace('photoyna.co.kr', '').replace('동아닷컴DB', '').replace('News1', '')
        text = text.replace('superdoo82yna.co.kr', '').replace('padoseoul.co.kr', '').replace('자료제공', '').replace('출처 :', '')
        text = text.replace('hjmnewsis.com', '').replace('pak7130newsis.com', '').replace('myjsnewsis.com', '').replace('twopeoplehankyung.com', '')
        text = text.replace('모바일한경은 프리미엄 채널입니다.', '').replace('dooleekyunghyang.com', '')
        text = text.replace('사진｜Gettyimages이매진스', '').replace('* 아래 텍스트는 실제 방송 내용과 차이가 있을 수 있으니 보다 정확한 내용은 방송으로 확인해주시기 바랍니다.', '')
        text = text.replace('퍼스트  언론,  <한겨레21>  정기구독으로  응원하기!  전화신청▶ 1566-9595 인터넷신청▶   http://bit.ly/1HZ0DmD카톡 선물하기▶  http://bit.ly/1UELpok  공식 SNS   Copyrights  한겨레신문사, 무단전재 및 재배포 금지<한겨레는 한국온라인신문협회의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.', '')
        text = text.replace('psykimsyna.co.kr', '').replace('사진동아일보 DB', '').replace('사진SBS캡쳐', '').replace('CBS노컷뉴스', '')
        text = text.replace('/VAST엔터테인먼트', '')
        text = text.replace('※은 일상 생활에서 겪은 황당한 이야기나 어이없는 갑질 등을 고발하는 코너입니다. 다른 독자들과 공유하고 싶은 사연이 있다면 보내주세요. 그중 채택해 에서 다루고 전문가 조언도 들어봅니다. 여러분의 사연을 보내실 곳은 jebohankyung.com입니다.', '')
        text = text.replace('News', '').replace('이미지투데이', '').replace('jyaseoul.co.kr', '')
        text = text.replace('daunsoseoul.co.kr', '').replace('yohandonga.com', '')
        text = text.replace('☞','').replace('무릎ㆍ관절 무료수술','').replace('☞공짜로 연극ㆍ뮤지컬보기','')
        text = text.replace(' 세상을 보는 정직한 눈 <한겨레>  [한겨레신문 구독 | 한겨레21 구독] 한겨레신문사, 무단전재 및 재배포 금지<한겨레는 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.','')
        text = text.replace('[공짜로 연극ㆍ뮤지컬보기]','')
        text = text.replace('<8뉴스><앵커>','')
        text = text.replace('대한민국 희망언론! 경향신문, 구독신청(http://smile.khan.co.kr) -  경향신문 & 경향닷컴(www.khan.co.kr), 무단전재 및 재배포 금지〈경향닷컴은 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.','')
        text = text.replace('<세계닷컴은 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.','')
        text = text.replace('.로 11번째 사망자 발생◆ 신현준, 매니저 폭행 혐의로 피소◆ 남자팬티, 이제 가로로 벌어진다◆ 청년도 중소기업도 ','')
        text = text.replace('… 취업난 속 구인난은 계속    [ 세계일보 & Segye.com, 무단 전재 및 재배포 금지]','')
        text = text.replace('【서울】임영주 기자','')
        text = text.replace('▲ ⓒKBS ','')
        text = text.replace('무릎ㆍ관절]','').replace('무료수술]','')
        text = text.replace('에디트|유두선 웹캐스터 noixzongmail.com▶스포츠동아 인기화보[화보] 앨범내고 가수 도전하는 ','')
        text = text.replace('파격 노출','').replace('로 화제…영화 ','').replace('탤런트 김정민 (?)[화보] ‘이번엔 눈물쓰나미’…영화 ‘내사랑 내곁에’ 하지원 [화보] ‘섹시 입술’ 서지아, 매혹의 코리아 그라비아 화보[화보] 강혜정,한채영,허이재 주연…영화 ‘걸프렌즈’ 간담회  [화보] 성의 자유… 영화 ‘숏버스’ 스틸 컷  "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('▶스포츠동아 인기화보[화보] ‘아빠 앞이라…’ 애프터스쿨 유이의 수줍은 시구[화보] ‘파격 노출’ 로 화제…영화 ‘펜트하우스 코끼리’ [화보] ‘섹시 아이콘’ 이효리, 란제리룩도 ‘엣지있게’[화보] 앙드레김 패션쇼에 선 ‘우결커플’ 황정음 김용준 [화보] 연예계 최고 ‘꿀벅지’…애프터 스쿨 유이r> "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('[쿠키 톡톡]','')
        text = text.replace('에디트|유두선 웹캐스터 noixzongmail.com▶스포츠동아 인기화보[화보] ‘아빠 앞이라…’ 애프터스쿨 유이의 수줍은 시구[화보] ‘’ ‘펜트하우스 코끼리’ [화보] ‘섹시 아이콘’ 이효리, 란제리룩도 ‘엣지있게’[화보] 앙드레김 패션쇼에 선 ‘우결커플’ 황정음 김용준 [화보] 연예계 최고 ‘꿀벅지’…애프터 스쿨 유이r> "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('홈페이지: http://www.080114.net/0804080444무료전화: 080-4080-444 / 대표전화 : 043-651-7887 -----------------------------------------------------------------------------KT 080114는 경기불황에도 끊임없이 고객을 위해 먼저 다가가는 고객중심의 서비스 경영을 선두하는 소상공인을 후원하고 있습니다. 080114 고객무료 전화번호서비스는 고객에게는 견적/상담문의 시 통화료 부담을 줄이고 업체에는 고객을 당기는 디딤돌을 놓는 서비스입니다. 080 가입업체에게는 홈페이지 무료제작, 유지관리보수 및 온라인 보도자료의 혜택을 제공합니다.080고객무료전화 신청 및 가맹점, 대리점모집 관련 문의 : 1577-7942(www.080114.net )* 본 보도자료는 소상공인 지원을 위한 것이며 자료의 내용과 관련한 모든 책임은 제공자에 있습니다. donga.com & ePR news, 무단 전재 및 재배포 금지 "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('상담 및 제보는 전국 어디서나 국번 없이 1331번 인권상담전화를 통하면 전문상담원과 연결되며, 홈페이지(www.humanrights.go.kr), 이메일(hosohumanrights.go.kr), 편지(중구 을지로 1가 국가인권위원회), 팩스(02-2125-9812) 등을 통해 가능하다.','')
        text = text.replace('<한겨레>  [한겨레신문 구독 | 한겨레21 구독] 한겨레신문사, 무단전재 및 재배포 금지<한겨레는 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.','')
        text = text.replace('[머니투데이 보도자료 ]▶','')
        text = text.replace('※본 내용은 머니투데이의 편집 방향과 무관하며, 모든 책임은 정보 제공자에게 있습니다.','')
        text = text.replace('이진영 기자 ecoleedonga.com "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('김민현 기자(kiesheraldm.com) ※사진설명: 경찰청 여성청소년과 신영숙 경감과 경찰들이 국내 최초 IPTV 공공기관 양방향 홈채널 서비스 ‘행복세상 만들기’를 시청하고 있다.','')
        text = text.replace('청담금산한의원(www.ekumsan.co.kr) 한승섭 박사 (본 자료는 정보제공을 위한 보도자료입니다.','')
        text = text.replace('원성열 기자 serenodonga.com[화보]‘제7회 서울모터쇼’ 의 매혹적인 레이싱모델들[화보]‘2009 파리모터쇼’ 개막…친환경 소형차 각축[관련기사]‘6세대 폭스바겐 골프 TDI’ 공개  골프의 진화 “주인님, 주차도 제가…” "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('원성열 기자 serenodonga.com[화보]2006 부산 국제모터쇼 ‘폭스바겐’ 미녀들[화보]‘제7회 서울모터쇼’ 의 매혹적인 레이싱모델들 "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('◆사진설명: 한나라당 정몽준 대표가 22일 서울 여의도 중소기업중앙회에서 열린 중소기업정책간담회에서 인사말을 하고 있다.','')
        text = text.replace('이정연 기자 annjoydonga.com[화보]‘4人4色’ 브아걸, 뚜렷한 개성으로 인기몰이[화보]‘브라운아이드걸스’ 매력만점 스타화보 공개[관련기사]브아걸 손가인-나르샤 키스신?[관련기사]‘브아걸’ 가인 스크린데뷔 프로젝트   [관련기사]브라운아이드걸스, 7월 3집 발매 "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('스포츠동아 허민녕 기자 justindonga.com [화보]부산국제영화제 개봉작 ‘굿모닝 프레지던트’[화보]장동건-한채영 주연영화 ‘굿모닝 프레지던트’[관련기사]장동건 복귀작 ‘굿모닝 프레지던트’ 티저 포스터 공개[관련기사]장동건, “임기끝나고 퇴임하는 기분, 행복했다”[관련기사]‘완벽미남’ 장동건 “요즘 피부관리에 집중” ▲동아닷컴 정주희 기자 "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('[화보]잠옷? 외출복?…2010 봄/여름 프라다 컬렉션[화보]섹시하거나 충격적이거나…[화보]“몸 파는 장소만 달랐어요” 그녀의 고백 "세상을 보는 맑은 창이 되겠습니다','')
        text = text.replace("〈경향신문은 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.〉","").replace("- ⓒ 경향신문(www.khan.co.kr), 무단전재 및 재배포 금지","")
        text = text.replace("모바일 경향 [경향 뉴스진 | 경향신문 앱 | 모바일웹] | 공식 SNS 계정 [경향 트위터] [미투데이] [페이스북] [세상과 경향의 소통 커뮤니티]","")
        text = text.replace("편집자주","").replace("플레이어","").replace("본문 내용","")
        text = text.replace("입력:2014-01-0611:09:30","").replace("머니투데이방송의 기사에 대해 반론·정정·추후 보도를 청구하실 분은 아래의 연락처로 연락주시길 바랍니다.","")
        text = text.replace("저작권자","")
        text = text.replace("☞","")
        text = text.replace("】","").replace("【","").replace("▲","").replace("▶","").replace("◇","").replace("■","")
        text = text.replace("오류를 우회하기 위한 함수 추가","").replace("⇨","").replace("★","").replace("※","").replace("◀","").replace("◆","").replace("● ","").replace("○","")
        text = text.replace("△","").replace("▼","").replace("(adsbygoogle=window.adsbygoogle||[]).push({});","").replace("© 온라인 커뮤니티","").replace("// flash","").replace("function _flash_removeCallback() {}","")
        text = text.replace("스포츠월드 연예팀","").replace("ⓒ 스포츠월드 & Sportsworldi.com, 무단 전재 및 재배포 금지","")
        text = text.replace("머니투데이 스타일M ","").replace("[헤럴드생생뉴스]","").replace("[쿠키 연예]","").replace("OBS 독특한 연예뉴스","")
        text = text.replace("// flash","").replace("function _flash_removeCallback() {}","").replace("경향DB","").replace("","").replace("","").replace("","").replace("자료: 통계청 경제활동인구조사","")
        text = text.replace("(adsbygoogle=window.adsbygoogle||[]).push({});","").replace("","").replace("","").replace("","").replace("","").replace("","").replace("","")
        text = text.replace("[OSEN=이슈팀]","").replace("<온라인뉴스팀>","").replace("스포츠경향 뉴스를 네이버 뉴스 스탠드에서 만나 보세요. [‘MY뉴스’ 구독하기 ]","").replace("모바일 경향 [경향 뉴스진 | 경향신문 앱 | 모바일웹 ] | 공식 SNS 계정 [트위터] [미투데이] [페이스북]","").replace("- ⓒ 스포츠경향 & 경향닷컴(http://sports.khan.co.kr), 무단전재 및 재배포 금지","").replace("〈경향닷컴은 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.〉","")
        text = text.replace("- ⓒ 스포츠경향 & 경향닷컴(http://sports.khan.co.kr), 무단전재 및 재배포 금지","").replace("","").replace("","").replace("","").replace("","").replace("","").replace("","")
        text = text.replace("GoodNews Paper ⓒ 국민일보. 무단전재 및 재배포금지","").replace("[뉴스 미란다 원칙] 취재원과 독자에게는 국민일보 쿠키뉴스에 자유로이 접근할 권리와 반론·정정·추후 보도를 청구할 권리가 있습니다. 고충처리인(gochung@kmib.co.kr), 쿠키뉴스(kuki@kmib.co.kr)/전화:02-781-9711","")
        #text = text.replace('\n','')
        text = text.replace(';try;f.appendChild}catch});', '').replace('googletag.cmd.push );','').replace('googletag.cmd = googletag.cmd || ;', '')


        text = text.replace('게티이미지뱅크', '').replace('News', '').replace('이미지투데이', '').replace('jyaseoul.co.kr', '')
        text = text.replace('사진 = 연합뉴스', '').replace('사진 = JTBC', '')
        text = text.replace('사진=뉴시스', '').replace('출처 : instagram', '').replace('사진 / 시사포커스DB', '').replace('개의 댓글이 있습니다.', '')
        text = text.replace('사진:', '').replace('계정을 선택하시면 로그인·계정인증을 통해 댓글을 남기실 수 있습니다.', '')
        text = text.replace('삭제한 댓글은 다시 복구할 수 없습니다.','').replace('ⓒ게티이미지뱅크', '').replace('출처:', '')
        text = text.replace('본 기사는 시사주간지 의 고유 콘텐츠입니다. 외부게재시 개인은 출처와 링크를 밝혀주시고, 언론사는 전문게재의 경우 본사와 협의 바랍니다.', '')
        text = text.replace('여러분의 제보가 세상을 바꿀 수 있습니다. 세상을 건강하게 변화시키는 인사이트의 수많은 기사들은 여러분의 제보로부터 시작됩니다.', '')
        text = text.replace('개의 댓글이 있습니다.', '')
        text = text.replace('댓글달기로그인 후 작성 가능합니다.', '').replace('인터넷 법률신문의 모든 컨텐츠는 저작권법의 보호를 받으며 무단전제, 복사, 배포를 금합니다.', '')
        text = text.replace('기간설정 기본검색 상세검색','').replace('알아보기 먹어보기 둘러보기 즐겨보기 다녀보기 뽐내보기 읽어보기 느껴보기 살펴보기 함께보기', '')
        text = text.rstrip('\n')

        #text = re.sub('.*;','',text)
        #text = re.sub('googletag.*{','',text)
        #text = re.sub('googletag.*;','',text)
        #text = re.sub('.*}','',text)
        text = re.sub(r'[\(\[].*?[\)\]]', '', text)
        text = re.sub('댓글.*?제한됩니다.','', text, flags=re.DOTALL)
        text = re.sub('【.*?】','',text)
        text = re.sub('#.*}','', text, flags=re.DOTALL)
        text = re.sub('{.*?}','', text, flags=re.DOTALL)
        text = re.sub('베이비뉴스.*?쓰겠습니다.', '', text, flags=re.DOTALL)
        text = re.sub('글 =.*?있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('전체보기 산업.*?입력', '', text, flags=re.DOTALL)
        text = re.sub('해당 언론사가.*?질 수 있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('NSP통신/NSP.*?않습니다.', '', text, flags=re.DOTALL)
        text = re.sub('허프포스트UK의.*?편집한 것입니다.', '', text, flags=re.DOTALL)
        text = re.sub('에듀동아.*?없습니다.', '', text, flags=re.DOTALL)
        text = re.sub('글 트래블투데이.*?한줄리포터가 없습니다.', '', text, flags=re.DOTALL)
        text = re.sub('사진.*?제공','', text, flags=re.DOTALL)
        text = re.sub('사진.*?인스타그램','', text, flags=re.DOTALL)
        text = re.sub('【.*】','',text)
        text = text.replace(']', '')
        text = re.sub('저작권자 © 금강일보.*?있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('저작권자 © 불교공뉴스.*?쓰겠습니다.', '', text, flags=re.DOTALL)
        text = re.sub('저작권자 © 시사오늘.*?담당합니다.', '', text, flags=re.DOTALL)
        text = re.sub('뒤로기사목록.*?있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('#.*?}','', text, flags=re.DOTALL)
        text = re.sub('사진=.*?엔터테인먼트', '',text, flags=re.DOTALL)
        text = re.sub('사진=.*?캡쳐', '',text, flags=re.DOTALL)
        text = re.sub('사진=.*?DB', '',text, flags=re.DOTALL)
        text = re.sub('사진출처=.*?캡처', '',text, flags=re.DOTALL)
        text = re.sub('사진이나 영상의 불법촬영유포,.*?지원받을 수 있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('<!--.*?-->', '', text, flags=re.DOTALL)
        text = re.sub('var.*?;', '', text, flags=re.DOTALL)   
        
        try: 
            text = text[:text.rindex('다.')+2]
            return text
        except:
            return 0
        
        
    def nv_article(html):
    
        text = html.select_one("div#articleBodyContents")
        if not text:
            text = html.select_one("div#articeBody")
        if text:
            text = text.text
            return replace_sub(text)
        else:
            return 0

    def etc_article(html):

        tlist = html.select('''
        div#article-view-content-div, article#article-view-content-div, div.vcon_con, div#textBody, div.view_txt, 
        div.article.detailCont, div.cont_cont, td.view_r, div#articleText, div.txtBox, section#ndArtBody, div#post-content,
        div#textinput, div.rns_text, div.view_cnt, div#viewConts, div.news_contents, div#news_body_area, div#newsContents,
        div.vcon_in.articleContent, div.contentView, div#content_body, div#view_content, div#article, div.txt_article,
        div.article_body, div.content_print, td#ct, div#article_body, div.bodyarea, div.editor_area, div#news_body_id,
        div#act-newsbody, div#print_arti
        ''')
        
        if tlist:
            text = [t.text for t in tlist]
            text = ' '.join(text)
            return replace_sub(text)
            
        else:
            plist = html.select('p')
            text = [t.text for t in plist]
            text = ' '.join(text)
            return replace_sub(text)
            
            

    if raw:
        html = BeautifulSoup(raw, "lxml")
        text = nv_article(html)

        if not text: #여기에 네이버 외에 다른 기사 파일 정리
            if 'moved' in raw:
                url = html.find('a').get('href')
                try:
                    raw2 = requests.get(url, headers={'User-Agent':'Mozilla/5.0'}, timeout=10)
                except:
                    return 0

                html2 = BeautifulSoup(raw2.text, "lxml")
                if 'naver' in url:
                    text = nv_article(html2)
                else:
                    text = etc_article(html2)
                    
            elif '다.' in raw:
                text = etc_article(html)

        return text
    
    else:
        return 0
    

    
import os
import re
import openpyxl
import calendar
from bs4 import BeautifulSoup
from pathos.multiprocessing import ProcessingPool as Pool
import pandas as pd
import time

cal = calendar.Calendar()

query = "여성"
query1 = "#1_" + query
query2 = "#2_" + query
year = 2019
urllist = list()
count = 0
for month in range(1, 13):
        monthdays = [d for d in cal.itermonthdays(year, month) if d != 0]
        for day in monthdays:
            
            date1 = str(year) + "." + str(month).zfill(2) + "." + str(day).zfill(2)
            date2 = date1.replace(".","")
            print(date1)
            
            xlsx_name1 = os.path.join(os.path.dirname(os.getcwd()), 'xlsx_data', query, query1, '#1_'+ str(year) + '_'+query, 
                                     '{}.xlsx'.format("#1_"+date2+"_"+query))
            myworkbook=openpyxl.load_workbook(xlsx_name1)
            worksheet= myworkbook.get_sheet_by_name('Sheet')
            
            
            xlsx_name2 = os.path.join(os.path.dirname(os.getcwd()), 'xlsx_data', query, query2, '#2_'+ str(year) + '_'+query, 
                                     '{}.xlsx'.format("#2_"+date2+"_"+query))
            wb = openpyxl.Workbook()
            sheet = wb.active
            sheet.append(["title", "source", "date", "text"])
            wb.save(xlsx_name2)
            
            book = openpyxl.load_workbook(xlsx_name2)
            writer = pd.ExcelWriter(xlsx_name2, engine='openpyxl')
            writer.book = book
            writer.sheets = {ws.title: ws for ws in book.worksheets}            
            
            start=time.time()

            for i in range(2, worksheet.max_row, 10):
                
                title, source, date, raw = list(), list(), list(), list()
                
                for j in range(10):
                    if i+j > worksheet.max_row:
                        break
                    title.append(worksheet.cell(row=i+j, column=1).value)
                    source.append(worksheet.cell(row=i+j, column=2).value)
                    date.append(worksheet.cell(row=i+j, column=3).value)
                    raw.append(worksheet.cell(row=i+j, column=4).value)
                
                with Pool(10) as p:
                    text = p.map(html_extract, raw)
                    
                d = pd.DataFrame({"title": title, "source": source, 
                                      "date": date, "text": text})
                
                for k in range(len(d.index)):
                    if d.loc[k, 'text'] == 0:
                        turl = worksheet.cell(row=i+k, column=5).value
                        if turl:
                            if 'http://' in turl:
                                tturl = re.sub('http://.*?/', '', turl, flags=re.DOTALL)
                                ttturl = turl.replace(tturl, '')
                                if ttturl not in urllist:
                                    count += 1
                                    urllist.append(ttturl)
                                    print(count, turl)
                                
                            elif 'https://' in turl:
                                tturl = re.sub('https://.*?/', '', turl, flags=re.DOTALL)
                                ttturl = turl.replace(tturl, '')
                                if ttturl not in urllist:
                                    count += 1
                                    urllist.append(ttturl)
                                    print(count, turl)
                                
                            
                d = d[d.text != 0]
                
                for sheetname in writer.sheets:
                    d.to_excel(writer,sheet_name=sheetname, startrow=writer.sheets[sheetname].max_row, 
                               index = False,header= False)
                
            writer.save()
            elapsed = (time.time() - start)  
            print("\n","time elapsed is :", elapsed)
            print('=======================================================================')
# Out:
# 2019.01.01
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:238: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# 1 http://www.gukjenews.com/news/articleView.html?idxno=1047684
# 2 http://www.wikitree.co.kr/main/news_view.php?id=393558
# 3 http://www.nbnnews.co.kr/news/articleView.html?idxno=218288
# 4 http://www.topstarnews.net/news/articleView.html?idxno=558075
# 5 http://www.obsnews.co.kr/news/articleView.html?idxno=1134150
# 6 http://www.ilyosisa.co.kr/news/articleView.html?idxno=201838
# 7 http://www.fntoday.co.kr/news/articleView.html?idxno=176005
# 8 http://medipana.com/news/news_viewer.asp?NewsNum=232873&MainKind=A&NewsKind=5&vCount=12&vKind=1
# 9 http://www.kihoilbo.co.kr/?mod=news&act=articleView&idxno=785097
# 10 http://www.joongdo.co.kr/main/view.php?key=20181231010012358
# 11 http://www.christiantoday.co.kr/news/318952
# 12 http://www.joongboo.com/news/articleView.html?idxno=1316189
# 13 http://www.kyeongin.com/main/view.php?key=20190101010000097
#  time elapsed is : 33.5778169631958
# =======================================================================
# 2019.01.28
# 499 http://www.gasnews.com/news/articleView.html?idxno=85932
# 500 http://www.edupress.kr/news/articleView.html?idxno=3289
# 501 http://ujnews.co.kr/news/newsview.php?ncode=1065572726978161
# 502 http://www.cstimes.com/?mod=news&act=articleView&idxno=295391
#
#  time elapsed is : 93.06906008720398
# =======================================================================
# 2019.01.29
# 503 http://www.radiokorea.com/news/article.php?uid=306754
# 504 http://www.ekn.kr/news/article.html?no=412374
#
#  time elapsed is : 136.2045817375183
# =======================================================================
# 2019.01.30
# 505 http://www.gnetimes.co.kr/news/articleView.html?idxno=52029
# 506 https://www.insight.co.kr/news/207867
#
#  time elapsed is : 91.55018281936646
# =======================================================================
# 2019.01.31
# 507 http://www.gosiweek.com/8114
#
#  time elapsed is : 90.27532982826233
# =======================================================================
# 2019.02.01
#
#  time elapsed is : 96.56266617774963
# =======================================================================
# 2019.02.02
#
#  time elapsed is : 32.54413080215454
# =======================================================================
# 2019.02.03
#
#  time elapsed is : 25.032660722732544
# =======================================================================
# 2019.02.04
#
#  time elapsed is : 23.82896113395691
# =======================================================================
# 2019.02.05
#
#  time elapsed is : 19.48635482788086
# =======================================================================
# 2019.02.06
#
#  time elapsed is : 31.55204701423645
# =======================================================================
# 2019.02.07
#
#  time elapsed is : 65.11362409591675
# =======================================================================
# 2019.02.08
# 508 https://science.ytn.co.kr/program/program_view.php?s_mcd=0082&s_hcd=&key=201902081630055010
# 509 http://www.thepingpong.co.kr/news/articleView.html?idxno=4369
#
#  time elapsed is : 63.20963788032532
# =======================================================================
# 2019.02.09
#
#  time elapsed is : 22.09658122062683
# =======================================================================
# 2019.02.10
#
#  time elapsed is : 25.022380828857422
# =======================================================================
# 2019.02.11
# 510 http://www.incheontoday.com/news/articleView.html?idxno=113158
# 511 https://nc.asiae.co.kr/view.htm?idxno=2019021114402542607
# 512 http://digitalchosun.dizzo.com/site/data/html_dir/2019/02/11/2019021180086.html
#
#  time elapsed is : 83.66935777664185
# =======================================================================
# 2019.02.12
# 513 http://www.usjournal.kr/news/newsview.php?ncode=1065596843222247
#
#  time elapsed is : 85.72169709205627
# =======================================================================
# 2019.02.13
#
#  time elapsed is : 86.058189868927
# =======================================================================
# 2019.02.14
#
#  time elapsed is : 114.85871767997742
# =======================================================================
# 2019.02.15
# 514 http://www.ziksir.com/ziksir/view/7809
# 515 http://www.m-i.kr/news/articleView.html?idxno=496277
#
#  time elapsed is : 102.19845771789551
# =======================================================================
# 2019.02.16
#
#  time elapsed is : 26.549232959747314
# =======================================================================
# 2019.02.17
#
#  time elapsed is : 96.1503336429596
# =======================================================================
# 2019.02.18
# 516 http://www.viewsnnews.com/article?q=166399
#
#  time elapsed is : 138.78080463409424
# =======================================================================
# 2019.02.19
# 517 https://radio.ytn.co.kr/program/?f=2&id=60804&s_mcd=0214&s_hcd=01
#
#  time elapsed is : 96.12763500213623
# =======================================================================
# 2019.02.20
#
#  time elapsed is : 130.39831829071045
# =======================================================================
# 2019.02.21
#
#  time elapsed is : 92.22178792953491
# =======================================================================
# 2019.02.22
#
#  time elapsed is : 61.69279670715332
# =======================================================================
# 2019.02.23
#
#  time elapsed is : 18.465327262878418
# =======================================================================
# 2019.02.24
# 518 http://www.weeklytrade.co.kr/news/view.html?section=1&category=136&item=&no=49865
#
#  time elapsed is : 32.70107698440552
# =======================================================================
# 2019.02.25
#
#  time elapsed is : 101.71177697181702
# =======================================================================
# 2019.02.26
# 519 https://www.ibabynews.com/news/articleView.html?idxno=72318
# 520 https://www.hidoc.co.kr/healthstory/news/C0000453376
#
#  time elapsed is : 98.73806023597717
# =======================================================================
# 2019.02.27
#
#  time elapsed is : 134.8097643852234
# =======================================================================
# 2019.02.28
#
#  time elapsed is : 90.00437474250793
# =======================================================================
# 2019.03.01
#
#  time elapsed is : 35.88485527038574
# =======================================================================
# 2019.03.02
#
#  time elapsed is : 31.76806879043579
# =======================================================================
# 2019.03.03
#
#  time elapsed is : 33.218385219573975
# =======================================================================
# 2019.03.04
#
#  time elapsed is : 72.51186084747314
# =======================================================================
# 2019.03.05
#
#  time elapsed is : 79.0119698047638
# =======================================================================
# 2019.03.06
# 521 http://www.mhns.co.kr/news/articleView.html?idxno=200931
#
#  time elapsed is : 70.42006635665894
# =======================================================================
# 2019.03.07
#
#  time elapsed is : 95.65757656097412
# =======================================================================
# 2019.03.08
#
#  time elapsed is : 96.66609477996826
# =======================================================================
# 2019.03.09
#
#  time elapsed is : 33.82413840293884
# =======================================================================
# 2019.03.10
#  time elapsed is : 36.1510443687439
# =======================================================================
# 2019.03.11
# 522 http://www.kidstvnews.co.kr/view.php?ud=2019031118535468658b70d496a5_29
# 523 http://www.fortunekorea.co.kr/news/articleView.html?idxno=10956
#
#  time elapsed is : 101.32515406608582
# =======================================================================
# 2019.03.12
#
#  time elapsed is : 124.42142343521118
# =======================================================================
# 2019.03.13
# 524 http://www.ekoreanews.co.kr/news/articleView.html?idxno=30502
#
#  time elapsed is : 118.48617959022522
# =======================================================================
# 2019.03.14
#
#  time elapsed is : 136.32609367370605
# =======================================================================
# 2019.03.15
#
#  time elapsed is : 119.58314347267151
# =======================================================================
# 2019.03.16
#
#  time elapsed is : 30.529913425445557
# =======================================================================
# 2019.03.17
#
#  time elapsed is : 34.28517985343933
# =======================================================================
# 2019.03.18
# 525 http://www.jejutwn.com/news/article.html?no=24290
# 526 http://www.newsinside.kr/news/articleView.html?idxno=600281
# 527 http://www.engdaily.com/news/articleView.html?idxno=9453
# 528 http://www.kndaily.co.kr/news/articleView.html?idxno=75938
# 529 http://www.eduinnews.co.kr/news/articleView.html?idxno=12574
# 530 http://www.jobnjoy.com/portal/joy/life_view.jsp?nidx=330709&depth1=2&depth2=2&depth3=4
#
#  time elapsed is : 101.59584474563599
# =======================================================================
# 2019.03.19
# 531 http://www.startuptoday.co.kr/news/articleView.html?idxno=21860
# 532 http://www.fins.co.kr/news/articleView.html?idxno=80017
# 533 http://www.newstof.com/news/articleView.html?idxno=1380
#
#  time elapsed is : 93.20190691947937
# =======================================================================
# 2019.03.20
# 534 http://www.ecomedia.co.kr/news/newsview.php?ncode=1065571758062946
#
#  time elapsed is : 84.67435622215271
# =======================================================================
# 2019.03.21
#
#  time elapsed is : 110.16441798210144
# =======================================================================
# 2019.03.22
# 535 http://www.earlyadopter.co.kr/123775
#
#  time elapsed is : 52.72086215019226
# =======================================================================
# 2019.03.23
#
#  time elapsed is : 25.40252375602722
# =======================================================================
# 2019.03.24
# 536 http://topclass.chosun.com/board/view.asp?catecode=L&tnu=201904100014
#
#  time elapsed is : 38.007089376449585
# =======================================================================
# 2019.03.25
#
#  time elapsed is : 87.21223258972168
# =======================================================================
# 2019.03.26
# 537 https://www.gnmbc.co.kr/post/65420
#
#  time elapsed is : 75.16450452804565
# =======================================================================
# 2019.03.27
# 538 https://www.jungle.co.kr/magazine/201004
# 539 http://mkhealth.co.kr/NEWS/01/view.php?NCode=MKH190327001
#
#  time elapsed is : 79.86145353317261
# =======================================================================
# 2019.03.28
#
#  time elapsed is : 121.15724658966064
# =======================================================================
# 2019.03.29
# 540 http://golfhankook.hankooki.com/01_news/NewsView.php?category=13&gsno=10229402
#
#  time elapsed is : 67.58055067062378
# =======================================================================
# 2019.03.30
#
#  time elapsed is : 33.25429606437683
# =======================================================================
# 2019.03.31
#
#  time elapsed is : 52.74863648414612
# =======================================================================
# 2019.04.01
# 541 https://www.mbcgw.com/post/65588
#
#  time elapsed is : 125.23044061660767
# =======================================================================
# 2019.04.02
# 542 http://www.footballjournal.co.kr/news/articleView.html?idxno=9633
#
#  time elapsed is : 82.00286173820496
# =======================================================================
# 2019.04.03
#
#  time elapsed is : 89.89947438240051
# =======================================================================
# 2019.04.04
#
#  time elapsed is : 81.47510576248169
# =======================================================================
# 2019.04.05
# 543 http://www.eroun.net/news/articleView.html?idxno=5076
#
#  time elapsed is : 59.289360761642456
# =======================================================================
# 2019.04.06
# 544 http://www.beyondpost.co.kr/view.php?ud=20190406164450453892b25ecb1b_30
#
#  time elapsed is : 17.139833688735962
# =======================================================================
# 2019.04.07
#
#  time elapsed is : 34.726622581481934
# =======================================================================
# 2019.04.08
# 545 http://www.bulgyofocus.net/news/articleView.html?idxno=80481
#
#  time elapsed is : 78.41283202171326
# =======================================================================
# 2019.04.09
# 546 http://www.mpmbc.co.kr/bbs/board.php?bo_table=news&wr_id=180212&sca=9%EC%8B%9C%EB%89%B4%EC%8A%A4%EB%8D%B0%EC%8A%A4%ED%81%AC
#
#  time elapsed is : 79.86181402206421
# =======================================================================
# 2019.04.10
#
#  time elapsed is : 89.05463719367981
# =======================================================================
# 2019.04.11
# 547 http://df.gamechosun.co.kr/board/view.php?bid=report&num=3413731
#
#  time elapsed is : 101.16467881202698
# =======================================================================
# 2019.04.12
# 548 https://www.dailysecu.com/?mod=news&act=articleView&idxno=48694
#
#  time elapsed is : 71.43617558479309
# =======================================================================
# 2019.04.13
#
#  time elapsed is : 27.666478633880615
# =======================================================================
# 2019.04.14
#
#  time elapsed is : 31.557647466659546
# =======================================================================
# 2019.04.15
# 549 https://feedapi.cloud.sbs.co.kr/feed-api/article_hub/G10009460709
#
#  time elapsed is : 89.33374261856079
# =======================================================================
# 2019.04.16
# 550 http://www.safetynews.co.kr/news/articleView.html?idxno=120629
# 551 http://goodnews1.com/news/news_view.asp?seq=87281
#
#  time elapsed is : 78.51330590248108
# ...
#
#  time elapsed is : 111.85768961906433
# =======================================================================
# 2019.09.20
#
#  time elapsed is : 66.22448945045471
# =======================================================================
# 2019.09.21
#
#  time elapsed is : 20.07671284675598
# =======================================================================
# 2019.09.22
#
#  time elapsed is : 40.6907057762146
# =======================================================================
# 2019.09.23
#
#  time elapsed is : 70.5266764163971
# =======================================================================
# 2019.09.24
#
#  time elapsed is : 66.09181642532349
# =======================================================================
# 2019.09.25
#
#  time elapsed is : 73.41156220436096
# =======================================================================
# 2019.09.26
# 628 http://www.womaneconomy.kr/news/articleView.html?idxno=81034
# 629 http://www.cbci.co.kr/news/articleView.html?idxno=327484
#
#  time elapsed is : 67.70823621749878
# =======================================================================
# 2019.09.27
# 630 http://www.hyunchuk.co.kr/news/8771
#
#  time elapsed is : 62.701788663864136
# =======================================================================
# 2019.09.28
#
#  time elapsed is : 18.088823080062866
# =======================================================================
# 2019.09.29
#
#  time elapsed is : 30.963162422180176
# =======================================================================
# 2019.09.30
# 631 http://www.globalmakers.co.kr/view.php?ud=201909300912512649d3244b4fed_39
# 632 http://www.newsclaim.co.kr/news/articleView.html?idxno=2085
# 633 http://www.lcnews.co.kr/news/articleView.html?idxno=1257
#
#  time elapsed is : 100.58025074005127
# =======================================================================
# 2019.10.01
# 634 http://www.efnews.co.kr/news/articleView.html?idxno=81176
# 635 http://www.maeilnews.co.kr/news/article.html?no=5160
# 636 http://www.newslock.co.kr/news/articleView.html?idxno=21850
# 637 http://www.imwood.co.kr/news/articleView.html?idxno=23483
#
#  time elapsed is : 77.62236261367798
# =======================================================================
# 2019.10.02
#
#  time elapsed is : 64.72815585136414
# =======================================================================
# 2019.10.03
#
#  time elapsed is : 36.55113172531128
# =======================================================================
# 2019.10.04
# 638 http://www.thekpm.com/view.php?ud=20191004160736385048e3dd6dd5_17
#
#  time elapsed is : 57.34164762496948
# =======================================================================
# 2019.10.05
#
#  time elapsed is : 17.601940393447876
# =======================================================================
# 2019.10.06
#
#  time elapsed is : 31.612351417541504
# =======================================================================
# 2019.10.07
#  time elapsed is : 82.86927318572998
# =======================================================================
# 2019.10.08
# 639 http://www.newstnt.com/news/articleView.html?idxno=38765
# 640 http://www.consumuch.com/news/articleView.html?idxno=46085
#
#  time elapsed is : 72.50330758094788
# =======================================================================
# 2019.10.09
# 641 http://www.aitimes.com/news/articleView.html?idxno=120085
#
#  time elapsed is : 30.104787349700928
# =======================================================================
# 2019.10.10
#
#  time elapsed is : 78.0950345993042
# =======================================================================
# 2019.10.11
#
#  time elapsed is : 61.832741498947144
# =======================================================================
# 2019.10.12
#
#  time elapsed is : 19.449371099472046
# =======================================================================
# 2019.10.13
# 642 http://www.mediawatch.kr/news/article.html?no=254353
#
#  time elapsed is : 31.524504899978638
# =======================================================================
# 2019.10.14
# 643 http://www.sjsori.com/news/articleView.html?idxno=39980
# 644 http://realty.chosun.com/site/data/html_dir/2019/10/13/2019101300783.html
#
#  time elapsed is : 66.618967294693
# =======================================================================
# 2019.10.15
# 645 http://coinreaders.com/5677
#
#  time elapsed is : 81.95294523239136
# =======================================================================
# 2019.10.16
#
#  time elapsed is : 74.1439700126648
# =======================================================================
# 2019.10.17
#
#  time elapsed is : 70.56029844284058
# =======================================================================
# 2019.10.18
# 646 https://www.ajunews.com/view/20191018181627952
# 647 https://decenter.kr/NewsView/1VPKJXYZZR
#
#  time elapsed is : 62.194459676742554
# =======================================================================
# 2019.10.19
#
#  time elapsed is : 21.329877138137817
# =======================================================================
# 2019.10.20
#
#  time elapsed is : 26.728999137878418
# =======================================================================
# 2019.10.21
#
#  time elapsed is : 81.0535204410553
# =======================================================================
# 2019.10.22
# 648 http://www.kdfnews.com/news/articleView.html?idxno=40023
# 649 http://www.mrepublic.co.kr/news/articleView.html?idxno=41073
#
#  time elapsed is : 71.21844363212585
# =======================================================================
# 2019.10.23
#
#  time elapsed is : 95.6587073802948
# =======================================================================
# 2019.10.24
# 650 http://www.tfmedia.co.kr/news/article.html?no=74761
#
#  time elapsed is : 76.89612102508545
# =======================================================================
# 2019.10.25
#
#  time elapsed is : 66.49798464775085
# =======================================================================
# 2019.10.26
#
#  time elapsed is : 18.02600860595703
# =======================================================================
# 2019.10.27
#
#  time elapsed is : 28.169713735580444
# =======================================================================
# 2019.10.28
# 651 https://www.g1tv.co.kr/index.php?type=news820&page=1&nth=0&viewNum=214742
#
#  time elapsed is : 64.02860569953918
# =======================================================================
# 2019.10.29
# 652 http://www.pennmike.com/news/articleView.html?idxno=23880
# 653 https://asiatime.co.kr/news/newsview.php?ncode=1065600217048108
# 654 https://www.asiatime.co.kr/news/newsview.php?ncode=1065577660696863
#
#  time elapsed is : 68.74027395248413
# =======================================================================
# 2019.10.30
#
#  time elapsed is : 85.15763568878174
# =======================================================================
# 2019.10.31
# 655 http://www.newdaily.co.kr/news/article.html?no=91619
# 656 http://www.thereport.co.kr/news/articleView.html?idxno=6328
#
#  time elapsed is : 84.7665376663208
# =======================================================================
# 2019.11.01
# 657 https://www.chuksannews.co.kr/news/article.html?no=219944
#
#  time elapsed is : 50.12172985076904
# =======================================================================
# 2019.11.02
#
#  time elapsed is : 20.79866051673889
# =======================================================================
# 2019.11.03
#
#  time elapsed is : 24.840061902999878
# =======================================================================
# 2019.11.04
#
#  time elapsed is : 70.88134169578552
# =======================================================================
# 2019.11.05
#
#  time elapsed is : 77.28595447540283
# =======================================================================
# 2019.11.06
#
#  time elapsed is : 76.91136384010315
# =======================================================================
# 2019.11.07
# 658 http://www.kmaeil.com/news/articleView.html?idxno=202708
# 659 http://www.kdpress.co.kr/news/articleView.html?idxno=93375
#
#  time elapsed is : 61.61411094665527
# =======================================================================
# 2019.11.08
# 660 http://www.newsian.co.kr/news/articleView.html?idxno=37339
#
#  time elapsed is : 82.58690118789673
# =======================================================================
# 2019.11.09
#
#  time elapsed is : 20.43276619911194
# =======================================================================
# 2019.11.10
#
#  time elapsed is : 25.592538118362427
# =======================================================================
# 2019.11.11
# 661 http://www.worktoday.co.kr/news/articleView.html?idxno=5023
#
#  time elapsed is : 81.29248690605164
# =======================================================================
# 2019.11.12
# 662 http://news.inochong.org/detail.php?number=1945&thread=22r13
#
#  time elapsed is : 77.15346002578735
# =======================================================================
# 2019.11.13
#
#  time elapsed is : 93.57475709915161
# =======================================================================
# 2019.11.14
# 663 http://www.paxetv.com/news/articleView.html?idxno=81630
# 664 http://www.audioht.co.kr/news/articleView.html?idxno=10196
#
#  time elapsed is : 66.3827702999115
# =======================================================================
# 2019.11.15
#
#  time elapsed is : 54.74985957145691
# =======================================================================
# 2019.11.16
#
#  time elapsed is : 17.714840173721313
# =======================================================================
# 2019.11.17
#
#  time elapsed is : 28.874866247177124
# =======================================================================
# 2019.11.18
# 665 https://www.tfmedia.co.kr/news/article.html?no=76008
# 666 http://www.koreastocknews.com/news/articleView.html?idxno=48176
#
#  time elapsed is : 88.60914707183838
# =======================================================================
# 2019.11.19
# 667 https://ditoday.com/%ec%b5%9c%ec%9b%90%ec%a4%80-%ed%8e%91%ed%83%80%ec%9d%b4-%ec%bd%94%eb%a6%ac%ec%95%84-%eb%8c%80%ed%91%9c/
#
#  time elapsed is : 96.24788999557495
# =======================================================================
# 2019.11.20
# 668 http://news.appstory.co.kr/plan12494
#
#  time elapsed is : 129.60408926010132
# =======================================================================
# 2019.11.21
#
#  time elapsed is : 114.50435614585876
# =======================================================================
# 2019.11.22
#
#  time elapsed is : 52.40210747718811
# =======================================================================
# 2019.11.23
#
#  time elapsed is : 17.61184597015381
# =======================================================================
# 2019.11.24
#
#  time elapsed is : 32.754422426223755
# =======================================================================
# 2019.11.25
#
#  time elapsed is : 97.36471581459045
# =======================================================================
# 2019.11.26
#
#  time elapsed is : 78.13703751564026
# =======================================================================
# 2019.11.27
#
#  time elapsed is : 100.61695194244385
# =======================================================================
# 2019.11.28
# 669 http://mbcgn.kr/mbcgnnews/52992
#  time elapsed is : 110.72372484207153
# =======================================================================
# 2019.11.29
# 670 http://www.safetimes.co.kr/news/articleView.html?idxno=78198
#
#  time elapsed is : 100.70795106887817
# =======================================================================
# 2019.11.30
#
#  time elapsed is : 29.656810522079468
# =======================================================================
# 2019.12.01
# 671 https://www.sisa-news.com/news/article.html?no=122338
#
#  time elapsed is : 26.180010080337524
# =======================================================================
# 2019.12.02
#
#  time elapsed is : 114.48813056945801
# =======================================================================
# 2019.12.03
#
#  time elapsed is : 105.72392153739929
# =======================================================================
# 2019.12.04
# 672 https://www.inews365.com/news/article.html?no=603173
#
#  time elapsed is : 87.55946183204651
# =======================================================================
# 2019.12.05
#
#  time elapsed is : 107.74626350402832
# =======================================================================
# 2019.12.06
#
#  time elapsed is : 69.73863434791565
# =======================================================================
# 2019.12.07
#
#  time elapsed is : 21.82562255859375
# =======================================================================
# 2019.12.08
#
#  time elapsed is : 37.64709830284119
# =======================================================================
# 2019.12.09
# 673 http://www.press9.kr/news/articleView.html?idxno=40622
# 674 http://www.epnc.co.kr/news/articleView.html?idxno=92919
#
#  time elapsed is : 81.74982500076294
# =======================================================================
# 2019.12.10
#
#  time elapsed is : 71.64401936531067
# =======================================================================
# 2019.12.11
# 675 http://www.asiaarts.net/view.php?ud=201912111107357491992c130dbe_38
#
#  time elapsed is : 83.80929899215698
# =======================================================================
# 2019.12.12
#
#  time elapsed is : 83.07459020614624
# =======================================================================
# 2019.12.13
# 676 http://www.globale.co.kr/view.php?ud=2019121314004282528743e6153c_36
#
#  time elapsed is : 96.87304735183716
# =======================================================================
# 2019.12.14
#
#  time elapsed is : 20.43000078201294
# =======================================================================
# 2019.12.15
#
#  time elapsed is : 22.715623140335083
# =======================================================================
# 2019.12.16
#
#  time elapsed is : 74.60687184333801
# =======================================================================
# 2019.12.17
# 677 https://www.mediapia.co.kr/news/articleView.html?idxno=63753
#
#  time elapsed is : 74.7014331817627
# =======================================================================
# 2019.12.18
#
#  time elapsed is : 72.13576865196228
# =======================================================================
# 2019.12.19
# 678 https://www.maeilnews.co.kr/news/article.html?no=7497
#
#  time elapsed is : 83.34764313697815
# =======================================================================
# 2019.12.20
# 679 http://www.natv.go.kr/renew09/brd/news/news_vw.jsp?newsId=44062
#
#  time elapsed is : 63.86176037788391
# =======================================================================
# 2019.12.21
#
#  time elapsed is : 14.635034084320068
# =======================================================================
# 2019.12.22
#
#  time elapsed is : 23.441080570220947
# =======================================================================
# 2019.12.23
#
#  time elapsed is : 7079.683518409729
# =======================================================================
# 2019.12.24
#
#  time elapsed is : 47.49142074584961
# =======================================================================
# 2019.12.25
#
#  time elapsed is : 21.36624264717102
# =======================================================================
# 2019.12.26
# 680 https://www.news2day.co.kr/145184
# 681 http://www.nongup.net/news/articleView.html?idxno=21860
#
#  time elapsed is : 59.80038404464722
# =======================================================================
# 2019.12.27
# 682 http://4th.kr/View.aspx?No=639559
#
#  time elapsed is : 51.921058893203735
# =======================================================================
# 2019.12.28
#
#  time elapsed is : 13.495406150817871
# =======================================================================
# 2019.12.29
# 683 https://www.jejutwn.com/news/article.html?no=75028
#
#  time elapsed is : 31.693389654159546
# =======================================================================
# 2019.12.30
#
#  time elapsed is : 75.20883560180664
# =======================================================================
# 2019.12.31
# 684 http://www.thebigdata.co.kr/view.php?ud=201912312014257935e91b94b033_23

# %%
import requests
from bs4 import BeautifulSoup

url = 
raw = requests.get(url, headers={'User-Agent':'Mozilla/5.0'})
html = BeautifulSoup(raw.text, "lxml")

urllist = ['div#article-view-content-div', 'article#article-view-content-div', 'div.vcon_con', 'div#textBody', 'div.view_txt', 
        'div.article.detailCont', 'div.cont_cont', 'td.view_r', 'div#articleText', 'div.txtBox', 'section#ndArtBody', 'div#post-content',
        'div#textinput', 'div.rns_text', 'div.view_cnt', 'div#viewConts', 'div.news_contents', 'div#news_body_area', 'div#newsContents',
        'div.vcon_in.articleContent', 'div.contentView', 'div#content_body', 'div#view_content', 'div#article', 'div.txt_article',
        'div.article_body', 'div.content_print', 'td#ct', 'div#article_body', 'div.bodyarea', 'div.editor_area', 'div#news_body_id',
        'div#act-newsbody', 'div#print_arti']

if '다.' in raw:
    print(html)

text = html.select_one('')
print(text)

if '' in urllist:
    print(True)
