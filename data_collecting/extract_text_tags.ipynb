# %%
# 나중에 많이 짧은 뉴스는 생략하기. 
def html_extract(raw):
    from bs4 import BeautifulSoup
    import re
    import requests
    
    def replace_sub(text):
        
        text = text.replace("▶디지털 뉴스콘텐츠 이용규칙 보기", "").replace("저작권자 © 기호일보 무단전재 및 재배포 금지", "")
        text = text.replace(').push', '').replace('사진=연합뉴스', '').replace('/ TV조선 방송화면 캡처', '').replace('사진=뉴스1 제공', '')
        text = text.replace('사진출처: 온라인 커뮤니티', '').replace('/연합뉴스/', '').replace('▲ SBS <8뉴스> 화면 갈무리 ⓒ SBS', '')
        text = text.replace('< 경남신문의 콘텐츠는 저작권법의 보호를 받는 바, 무단전재·복사·재배포를 금합니다.', '').replace('ⓒ뉴시스', '')
        text = text.replace('기자의 다른 기사 보기', '').replace('◀ＥＮＤ▶', '')
        text = text.replace('독자와 공감을 통해 더 나은 내일을 만들겠습니다.', '')
        text = text.replace('여러분의 제보가 세상을 바꿀 수 있습니다. 세상을 건강하게 변화시키는 인사이트의 수많은 기사들은 여러분의 제보로부터 시작됩니다.', '')
        text = text.replace('당사의 허락없이 본 기사와 사진의 무단 전재 및 재배포를 금합니다.', '')
        text = text.replace('  저작권자 © 의협신문 무단전재 및 재배포 금지      편만섭 기자 다른기사 보기  ','')
        text = text.replace('<p>','')
        text = text.replace('<br>','')
        text = text.replace('<\p>','')
        text = text.replace('<\br>','')
        text = text.replace('사진=연합뉴스TV[헤럴드경제=모바일섹션]', '').replace('=', '').replace('사진제공연합뉴스', '')
        text = text.replace('동영상 뉴스', '').replace('사진연합뉴스', '').replace('/AP 연합뉴스', '')
        text = text.replace('사진제공', '').replace('ⓒ', '').replace('출처 AP 뉴시스', '').replace('©', '').replace('@', '')
        text = text.replace('삽화', '').replace('mtkhtyna.co.kr', '').replace('logosyna.co.kr', '').replace('changhani.co.kr', '')
        text = text.replace('ryousantayna.co.kr', '').replace('wooimaeil.com', '').replace('/뉴시스', '')
        text = text.replace('/퍼스퍼코리아', '').replace('/CICI', '').replace('kjh9326newsis.com', '').replace('제공|스포티비뉴스', '')
        text = text.replace('검찰 로고/뉴스1', '').replace('photonewsis.com', '').replace('photonewsis.com', '')
        text = text.replace('<<시각장애인 음성정보 지원을 위한 텍스트입니다>>', '').replace('/사진', '')
        text = text.replace('/뉴스1', '').replace('<저작권자 공감언론 뉴시스통신사. 무단전재-재배포 금지.>', '').replace('unsplash ', '')
        text = text.replace('kknphotokyunghyang.com', '').replace('SBS방송 캡처.', '').replace('사진게티이미지뱅크', '')
        text = text.replace('게티이미지 제공', '').replace('신한금융지주 제공', '').replace('사진pixabay', '').replace('ppkjmnewsis.com', '')
        text = text.replace('|연합뉴스', '').replace('photoyna.co.kr', '').replace('동아닷컴DB', '').replace('News1', '')
        text = text.replace('superdoo82yna.co.kr', '').replace('padoseoul.co.kr', '').replace('자료제공', '').replace('출처 :', '')
        text = text.replace('hjmnewsis.com', '').replace('pak7130newsis.com', '').replace('myjsnewsis.com', '').replace('twopeoplehankyung.com', '')
        text = text.replace('모바일한경은 프리미엄 채널입니다.', '').replace('dooleekyunghyang.com', '')
        text = text.replace('사진｜Gettyimages이매진스', '').replace('* 아래 텍스트는 실제 방송 내용과 차이가 있을 수 있으니 보다 정확한 내용은 방송으로 확인해주시기 바랍니다.', '')
        text = text.replace('퍼스트  언론,  <한겨레21>  정기구독으로  응원하기!  전화신청▶ 1566-9595 인터넷신청▶   http://bit.ly/1HZ0DmD카톡 선물하기▶  http://bit.ly/1UELpok  공식 SNS   Copyrights  한겨레신문사, 무단전재 및 재배포 금지<한겨레는 한국온라인신문협회의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.', '')
        text = text.replace('psykimsyna.co.kr', '').replace('사진동아일보 DB', '').replace('사진SBS캡쳐', '').replace('CBS노컷뉴스', '')
        text = text.replace('/VAST엔터테인먼트', '')
        text = text.replace('※은 일상 생활에서 겪은 황당한 이야기나 어이없는 갑질 등을 고발하는 코너입니다. 다른 독자들과 공유하고 싶은 사연이 있다면 보내주세요. 그중 채택해 에서 다루고 전문가 조언도 들어봅니다. 여러분의 사연을 보내실 곳은 jebohankyung.com입니다.', '')
        text = text.replace('News', '').replace('이미지투데이', '').replace('jyaseoul.co.kr', '')
        text = text.replace('daunsoseoul.co.kr', '').replace('yohandonga.com', '')
        text = text.replace('☞','').replace('무릎ㆍ관절 무료수술','').replace('☞공짜로 연극ㆍ뮤지컬보기','')
        text = text.replace(' 세상을 보는 정직한 눈 <한겨레>  [한겨레신문 구독 | 한겨레21 구독] 한겨레신문사, 무단전재 및 재배포 금지<한겨레는 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.','')
        text = text.replace('[공짜로 연극ㆍ뮤지컬보기]','')
        text = text.replace('<8뉴스><앵커>','')
        text = text.replace('대한민국 희망언론! 경향신문, 구독신청(http://smile.khan.co.kr) -  경향신문 & 경향닷컴(www.khan.co.kr), 무단전재 및 재배포 금지〈경향닷컴은 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.','')
        text = text.replace('<세계닷컴은 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.','')
        text = text.replace('.로 11번째 사망자 발생◆ 신현준, 매니저 폭행 혐의로 피소◆ 남자팬티, 이제 가로로 벌어진다◆ 청년도 중소기업도 ','')
        text = text.replace('… 취업난 속 구인난은 계속    [ 세계일보 & Segye.com, 무단 전재 및 재배포 금지]','')
        text = text.replace('【서울】임영주 기자','')
        text = text.replace('▲ ⓒKBS ','')
        text = text.replace('무릎ㆍ관절]','').replace('무료수술]','')
        text = text.replace('에디트|유두선 웹캐스터 noixzongmail.com▶스포츠동아 인기화보[화보] 앨범내고 가수 도전하는 ','')
        text = text.replace('파격 노출','').replace('로 화제…영화 ','').replace('탤런트 김정민 (?)[화보] ‘이번엔 눈물쓰나미’…영화 ‘내사랑 내곁에’ 하지원 [화보] ‘섹시 입술’ 서지아, 매혹의 코리아 그라비아 화보[화보] 강혜정,한채영,허이재 주연…영화 ‘걸프렌즈’ 간담회  [화보] 성의 자유… 영화 ‘숏버스’ 스틸 컷  "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('▶스포츠동아 인기화보[화보] ‘아빠 앞이라…’ 애프터스쿨 유이의 수줍은 시구[화보] ‘파격 노출’ 로 화제…영화 ‘펜트하우스 코끼리’ [화보] ‘섹시 아이콘’ 이효리, 란제리룩도 ‘엣지있게’[화보] 앙드레김 패션쇼에 선 ‘우결커플’ 황정음 김용준 [화보] 연예계 최고 ‘꿀벅지’…애프터 스쿨 유이r> "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('[쿠키 톡톡]','')
        text = text.replace('에디트|유두선 웹캐스터 noixzongmail.com▶스포츠동아 인기화보[화보] ‘아빠 앞이라…’ 애프터스쿨 유이의 수줍은 시구[화보] ‘’ ‘펜트하우스 코끼리’ [화보] ‘섹시 아이콘’ 이효리, 란제리룩도 ‘엣지있게’[화보] 앙드레김 패션쇼에 선 ‘우결커플’ 황정음 김용준 [화보] 연예계 최고 ‘꿀벅지’…애프터 스쿨 유이r> "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('홈페이지: http://www.080114.net/0804080444무료전화: 080-4080-444 / 대표전화 : 043-651-7887 -----------------------------------------------------------------------------KT 080114는 경기불황에도 끊임없이 고객을 위해 먼저 다가가는 고객중심의 서비스 경영을 선두하는 소상공인을 후원하고 있습니다. 080114 고객무료 전화번호서비스는 고객에게는 견적/상담문의 시 통화료 부담을 줄이고 업체에는 고객을 당기는 디딤돌을 놓는 서비스입니다. 080 가입업체에게는 홈페이지 무료제작, 유지관리보수 및 온라인 보도자료의 혜택을 제공합니다.080고객무료전화 신청 및 가맹점, 대리점모집 관련 문의 : 1577-7942(www.080114.net )* 본 보도자료는 소상공인 지원을 위한 것이며 자료의 내용과 관련한 모든 책임은 제공자에 있습니다. donga.com & ePR news, 무단 전재 및 재배포 금지 "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('상담 및 제보는 전국 어디서나 국번 없이 1331번 인권상담전화를 통하면 전문상담원과 연결되며, 홈페이지(www.humanrights.go.kr), 이메일(hosohumanrights.go.kr), 편지(중구 을지로 1가 국가인권위원회), 팩스(02-2125-9812) 등을 통해 가능하다.','')
        text = text.replace('<한겨레>  [한겨레신문 구독 | 한겨레21 구독] 한겨레신문사, 무단전재 및 재배포 금지<한겨레는 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.','')
        text = text.replace('[머니투데이 보도자료 ]▶','')
        text = text.replace('※본 내용은 머니투데이의 편집 방향과 무관하며, 모든 책임은 정보 제공자에게 있습니다.','')
        text = text.replace('이진영 기자 ecoleedonga.com "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('김민현 기자(kiesheraldm.com) ※사진설명: 경찰청 여성청소년과 신영숙 경감과 경찰들이 국내 최초 IPTV 공공기관 양방향 홈채널 서비스 ‘행복세상 만들기’를 시청하고 있다.','')
        text = text.replace('청담금산한의원(www.ekumsan.co.kr) 한승섭 박사 (본 자료는 정보제공을 위한 보도자료입니다.','')
        text = text.replace('원성열 기자 serenodonga.com[화보]‘제7회 서울모터쇼’ 의 매혹적인 레이싱모델들[화보]‘2009 파리모터쇼’ 개막…친환경 소형차 각축[관련기사]‘6세대 폭스바겐 골프 TDI’ 공개  골프의 진화 “주인님, 주차도 제가…” "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('원성열 기자 serenodonga.com[화보]2006 부산 국제모터쇼 ‘폭스바겐’ 미녀들[화보]‘제7회 서울모터쇼’ 의 매혹적인 레이싱모델들 "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('◆사진설명: 한나라당 정몽준 대표가 22일 서울 여의도 중소기업중앙회에서 열린 중소기업정책간담회에서 인사말을 하고 있다.','')
        text = text.replace('이정연 기자 annjoydonga.com[화보]‘4人4色’ 브아걸, 뚜렷한 개성으로 인기몰이[화보]‘브라운아이드걸스’ 매력만점 스타화보 공개[관련기사]브아걸 손가인-나르샤 키스신?[관련기사]‘브아걸’ 가인 스크린데뷔 프로젝트   [관련기사]브라운아이드걸스, 7월 3집 발매 "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('스포츠동아 허민녕 기자 justindonga.com [화보]부산국제영화제 개봉작 ‘굿모닝 프레지던트’[화보]장동건-한채영 주연영화 ‘굿모닝 프레지던트’[관련기사]장동건 복귀작 ‘굿모닝 프레지던트’ 티저 포스터 공개[관련기사]장동건, “임기끝나고 퇴임하는 기분, 행복했다”[관련기사]‘완벽미남’ 장동건 “요즘 피부관리에 집중” ▲동아닷컴 정주희 기자 "세상을 보는 맑은 창이 되겠습니다.','')
        text = text.replace('[화보]잠옷? 외출복?…2010 봄/여름 프라다 컬렉션[화보]섹시하거나 충격적이거나…[화보]“몸 파는 장소만 달랐어요” 그녀의 고백 "세상을 보는 맑은 창이 되겠습니다','')
        text = text.replace("〈경향신문은 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.〉","").replace("- ⓒ 경향신문(www.khan.co.kr), 무단전재 및 재배포 금지","")
        text = text.replace("모바일 경향 [경향 뉴스진 | 경향신문 앱 | 모바일웹] | 공식 SNS 계정 [경향 트위터] [미투데이] [페이스북] [세상과 경향의 소통 커뮤니티]","")
        text = text.replace("편집자주","").replace("플레이어","").replace("본문 내용","")
        text = text.replace("입력:2014-01-0611:09:30","").replace("머니투데이방송의 기사에 대해 반론·정정·추후 보도를 청구하실 분은 아래의 연락처로 연락주시길 바랍니다.","")
        text = text.replace("저작권자","")
        text = text.replace("☞","")
        text = text.replace("】","").replace("【","").replace("▲","").replace("▶","").replace("◇","").replace("■","")
        text = text.replace("오류를 우회하기 위한 함수 추가","").replace("⇨","").replace("★","").replace("※","").replace("◀","").replace("◆","").replace("● ","").replace("○","")
        text = text.replace("△","").replace("▼","").replace("(adsbygoogle=window.adsbygoogle||[]).push({});","").replace("© 온라인 커뮤니티","").replace("// flash","").replace("function _flash_removeCallback() {}","")
        text = text.replace("스포츠월드 연예팀","").replace("ⓒ 스포츠월드 & Sportsworldi.com, 무단 전재 및 재배포 금지","")
        text = text.replace("머니투데이 스타일M ","").replace("[헤럴드생생뉴스]","").replace("[쿠키 연예]","").replace("OBS 독특한 연예뉴스","")
        text = text.replace("// flash","").replace("function _flash_removeCallback() {}","").replace("경향DB","").replace("","").replace("","").replace("","").replace("자료: 통계청 경제활동인구조사","")
        text = text.replace("(adsbygoogle=window.adsbygoogle||[]).push({});","").replace("","").replace("","").replace("","").replace("","").replace("","").replace("","")
        text = text.replace("[OSEN=이슈팀]","").replace("<온라인뉴스팀>","").replace("스포츠경향 뉴스를 네이버 뉴스 스탠드에서 만나 보세요. [‘MY뉴스’ 구독하기 ]","").replace("모바일 경향 [경향 뉴스진 | 경향신문 앱 | 모바일웹 ] | 공식 SNS 계정 [트위터] [미투데이] [페이스북]","").replace("- ⓒ 스포츠경향 & 경향닷컴(http://sports.khan.co.kr), 무단전재 및 재배포 금지","").replace("〈경향닷컴은 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.〉","")
        text = text.replace("- ⓒ 스포츠경향 & 경향닷컴(http://sports.khan.co.kr), 무단전재 및 재배포 금지","").replace("","").replace("","").replace("","").replace("","").replace("","").replace("","")
        text = text.replace("GoodNews Paper ⓒ 국민일보. 무단전재 및 재배포금지","").replace("[뉴스 미란다 원칙] 취재원과 독자에게는 국민일보 쿠키뉴스에 자유로이 접근할 권리와 반론·정정·추후 보도를 청구할 권리가 있습니다. 고충처리인(gochung@kmib.co.kr), 쿠키뉴스(kuki@kmib.co.kr)/전화:02-781-9711","")
        #text = text.replace('\n','')
        text = text.replace(';try;f.appendChild}catch});', '').replace('googletag.cmd.push );','').replace('googletag.cmd = googletag.cmd || ;', '')


        text = text.replace('게티이미지뱅크', '').replace('News', '').replace('이미지투데이', '').replace('jyaseoul.co.kr', '')
        text = text.replace('사진 = 연합뉴스', '').replace('사진 = JTBC', '')
        text = text.replace('사진=뉴시스', '').replace('출처 : instagram', '').replace('사진 / 시사포커스DB', '').replace('개의 댓글이 있습니다.', '')
        text = text.replace('사진:', '').replace('계정을 선택하시면 로그인·계정인증을 통해 댓글을 남기실 수 있습니다.', '')
        text = text.replace('삭제한 댓글은 다시 복구할 수 없습니다.','').replace('ⓒ게티이미지뱅크', '').replace('출처:', '')
        text = text.replace('본 기사는 시사주간지 의 고유 콘텐츠입니다. 외부게재시 개인은 출처와 링크를 밝혀주시고, 언론사는 전문게재의 경우 본사와 협의 바랍니다.', '')
        text = text.replace('여러분의 제보가 세상을 바꿀 수 있습니다. 세상을 건강하게 변화시키는 인사이트의 수많은 기사들은 여러분의 제보로부터 시작됩니다.', '')
        text = text.replace('개의 댓글이 있습니다.', '')
        text = text.replace('댓글달기로그인 후 작성 가능합니다.', '').replace('인터넷 법률신문의 모든 컨텐츠는 저작권법의 보호를 받으며 무단전제, 복사, 배포를 금합니다.', '')
        text = text.replace('기간설정 기본검색 상세검색','').replace('알아보기 먹어보기 둘러보기 즐겨보기 다녀보기 뽐내보기 읽어보기 느껴보기 살펴보기 함께보기', '')
        text = text.rstrip('\n')

        #text = re.sub('.*;','',text)
        #text = re.sub('googletag.*{','',text)
        #text = re.sub('googletag.*;','',text)
        #text = re.sub('.*}','',text)
        text = re.sub(r'[\(\[].*?[\)\]]', '', text)
        text = re.sub('댓글.*?제한됩니다.','', text, flags=re.DOTALL)
        text = re.sub('【.*?】','',text)
        text = re.sub('#.*}','', text, flags=re.DOTALL)
        text = re.sub('{.*?}','', text, flags=re.DOTALL)
        text = re.sub('베이비뉴스.*?쓰겠습니다.', '', text, flags=re.DOTALL)
        text = re.sub('글 =.*?있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('전체보기 산업.*?입력', '', text, flags=re.DOTALL)
        text = re.sub('해당 언론사가.*?질 수 있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('NSP통신/NSP.*?않습니다.', '', text, flags=re.DOTALL)
        text = re.sub('허프포스트UK의.*?편집한 것입니다.', '', text, flags=re.DOTALL)
        text = re.sub('에듀동아.*?없습니다.', '', text, flags=re.DOTALL)
        text = re.sub('글 트래블투데이.*?한줄리포터가 없습니다.', '', text, flags=re.DOTALL)
        text = re.sub('사진.*?제공','', text, flags=re.DOTALL)
        text = re.sub('사진.*?인스타그램','', text, flags=re.DOTALL)
        text = re.sub('【.*】','',text)
        text = text.replace(']', '')
        text = re.sub('저작권자 © 금강일보.*?있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('저작권자 © 불교공뉴스.*?쓰겠습니다.', '', text, flags=re.DOTALL)
        text = re.sub('저작권자 © 시사오늘.*?담당합니다.', '', text, flags=re.DOTALL)
        text = re.sub('뒤로기사목록.*?있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('#.*?}','', text, flags=re.DOTALL)
        text = re.sub('사진=.*?엔터테인먼트', '',text, flags=re.DOTALL)
        text = re.sub('사진=.*?캡쳐', '',text, flags=re.DOTALL)
        text = re.sub('사진=.*?DB', '',text, flags=re.DOTALL)
        text = re.sub('사진출처=.*?캡처', '',text, flags=re.DOTALL)
        text = re.sub('사진이나 영상의 불법촬영유포,.*?지원받을 수 있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('<!--.*?-->', '', text, flags=re.DOTALL)
        text = re.sub('var.*?;', '', text, flags=re.DOTALL)   
        
        try: 
            text = text[:text.rindex('다.')+2]
            return text
        except:
            return 0
        
        
    def nv_article(html):
    
        text = html.select_one("div#articleBodyContents")
        if not text:
            text = html.select_one("div#articeBody")
        if text:
            text = text.text
            return replace_sub(text)
        else:
            return 0

    def etc_article(html):

        #tlist = html.select('''
        #div#article-view-content-div, article#article-view-content-div, div.vcon_con, div#textBody, div.view_txt, 
        #div.article.detailCont, div.cont_cont, td.view_r, div#articleText, div.txtBox, section#ndArtBody, div#post-content,
        #div#textinput, div.rns_text, div.view_cnt, div#viewConts, div.news_contents, div#news_body_area, div#newsContents,
        #div.vcon_in.articleContent, div.contentView, div#content_body, div#view_content, div#article, div.txt_article,
        #div.article_body, div.content_print, td#ct, div#article_body, div.bodyarea, div.editor_area, div#news_body_id,
        #div#act-newsbody, div#print_arti
        #''')
        
        #tlist = html.select('''
        #    div#article-view-content-div, article#article-view-content-div, div.vcon_con, div#textBody, div.view_txt, 
        #    div.article.detailCont, div.cont_cont, td.view_r, div#articleText, div.txtBox, section#ndArtBody, div#post-content,
        #    div#textinput, div.rns_text, div.view_cnt, div#viewConts, div.news_contents, div#news_body_area, div#newsContents,
        #    div.vcon_in.articleContent, div.contentView, div#content_body, div#view_content, div#article, div.txt_article,
        #    div.article_body, div.content_print, td#ct, div#article_body, div.bodyarea, div.editor_area, div#news_body_id,
        #    div#act-newsbody, div#print_arti,div[itemprop='articleBody'], div#articleBody, .vcon_con_intxt, div#_article,
        #    div.article-news-body, div.read, .cont-body, div#CmAdContent, #news_contents, section.nd-news-body, div#fontSzArea, 
        #    div.entry-content, div.article, div.news_content, div.col-12, #CLtag, #__newsBody__, div.viewConts, .news_bm,
        #    div.news_article, .rns_text, #divContentViewBox, .wikitree_content, .content, .tipro, div.article-body, #newsContent, 
        #    #news_content, .view_article, #content, .PhotoBox, div.article_txt, article.contents-txt, #fade_ad_postion, div#reportDetail,
        #    #d_content, .ContentCss, .par, .text, .newscon, div.cnt_view.news_body_area, .cont, div.float-right, div.newsContents, .view_cont,
        #    span.news_text, .news_con, div#GS_Content, div.view_body, div.col-xs-12, .article__body, iv.smartOutput, div.cont-body, div.contents,
        #    #txt_area, .contents-wrap
        #''')
        
        tlist = html.select('''
            div#article-view-content-div, article#article-view-content-div, div.vcon_con, div#textBody, div.view_txt, 
            div.article.detailCont, div.cont_cont, td.view_r, div#articleText, div.txtBox, section#ndArtBody, div#post-content, 
            #main_content, div#textinput, div.rns_text, div.view_cnt, div#viewConts, div.news_contents, div#news_body_area, 
            div#newsContents, div#content, div.vcon_in.articleContent, div.contentView, div#content_body, div#view_content, 
            div#article, div.txt_article, div.article_body, div.content_print, td#ct, div#article_body, div.bodyarea, div.editor_area, 
            div#news_body_id, #container > div.con_left > div.view_left_warp > div.left_text_box, div#act-newsbody, div#print_arti,
            div[itemprop='articleBody'], div#articleBody, .vcon_con_intxt, div#_article, div.article-news-body, div.read, .cont-body, 
            div#CmAdContent, #news_contents, section.nd-news-body, div#fontSzArea, div#font, div.entry-content, div.article, 
            div.news_content, div.col-12, #CLtag, #__newsBody__, div.viewConts, .news_bm, div.news_article, .rns_text, #divContentViewBox, 
            .wikitree_content, .content, .tipro, div.article-body, #newsContent, #news_content, .view_article, #content, .PhotoBox, 
            div.article_txt, article.contents-txt, #fade_ad_postion, div#reportDetail, #d_content, .ContentCss, .par, .text, .newscon, 
            div.cnt_view.news_body_area, .cont, div.float-right, div.newsContents, .view_cont, span.news_text, .news_con, div#GS_Content, 
            div.view_body, div.col-xs-12, .article__body, iv.smartOutput, div.cont-body, div.contents, #txt_area, 
            .contents-wrap, #container > div.inner > div.section > div.article_view > div.article_content, 
            #container > div.section_main > div.section > div > div.article > div > div, body > div.con > div.wrap2.tp2 > div.wr2_lt > div.v1d > div.v1d_con > div > div, 
            #article-view-content-div, #articleBody > div.conts, #newsView > div.rb-blog-body.rb-article, 
            #viewForm > div.media_area > div.media_body > div.text, #wrapper > div.sub-container > div.sub-layout > div.cont-article > article > div > div.cont-area, 
            div.newsTxt, body > div.vcon > div.vcon_in > div.v_lt > div > div.mi_lt > div.v1d > div.vtxt.detailCont, 
            #article-view-content-div > div.cont-body > div:nth-child(1), div.news-article-memo
        ''')
        
        if tlist:
            text = [t.text for t in tlist]
            text = ' '.join(text)
            return replace_sub(text)
            
        else:
            plist = html.select('p')
            text = [t.text for t in plist]
            text = ' '.join(text)
            return replace_sub(text)
            
            

    if raw:
        html = BeautifulSoup(raw, "lxml")
        text = nv_article(html)

        if not text: #여기에 네이버 외에 다른 기사 파일 정리
            if 'moved' in raw:
                url = html.find('a').get('href')
                try:
                    raw2 = requests.get(url, headers={'User-Agent':'Mozilla/5.0'}, timeout=10)
                except:
                    return 0

                html2 = BeautifulSoup(raw2.text, "lxml")
                if 'naver' in url:
                    text = nv_article(html2)
                else:
                    text = etc_article(html2)
                    
            elif '다.' in raw:
                text = etc_article(html)

        return text
    
    else:
        return 0
    

    
import os
import re
import openpyxl
import calendar
from bs4 import BeautifulSoup
from pathos.multiprocessing import ProcessingPool as Pool
import pandas as pd
import time

cal = calendar.Calendar()

query = "여성"
query1 = "#1_" + query
query2 = "#2_" + query
year = 2019
urllist = list()
testlist = list()
count = 0
for month in range(1, 13):
        monthdays = [d for d in cal.itermonthdays(year, month) if d != 0]
        for day in monthdays:
            
            date1 = str(year) + "." + str(month).zfill(2) + "." + str(day).zfill(2)
            date2 = date1.replace(".","")
            #print(date1)
            
            xlsx_name1 = os.path.join(os.path.dirname(os.getcwd()), 'xlsx_data', query, query1, '#1_'+ str(year) + '_'+query, 
                                     '{}.xlsx'.format("#1_"+date2+"_"+query))
            myworkbook=openpyxl.load_workbook(xlsx_name1)
            worksheet= myworkbook.get_sheet_by_name('Sheet')
            
            
            xlsx_name2 = os.path.join(os.path.dirname(os.getcwd()), 'xlsx_data', query, query2, '#2_'+ str(year) + '_'+query, 
                                     '{}.xlsx'.format("#2_"+date2+"_"+query))
            wb = openpyxl.Workbook()
            sheet = wb.active
            sheet.append(["title", "source", "date", "text"])
            wb.save(xlsx_name2)
            
            book = openpyxl.load_workbook(xlsx_name2)
            writer = pd.ExcelWriter(xlsx_name2, engine='openpyxl')
            writer.book = book
            writer.sheets = {ws.title: ws for ws in book.worksheets}            
            
            #start=time.time()

            for i in range(2, worksheet.max_row, 10):
                
                title, source, date, raw = list(), list(), list(), list()
                
                for j in range(10):
                    if i+j > worksheet.max_row:
                        break
                    title.append(worksheet.cell(row=i+j, column=1).value)
                    source.append(worksheet.cell(row=i+j, column=2).value)
                    date.append(worksheet.cell(row=i+j, column=3).value)
                    raw.append(worksheet.cell(row=i+j, column=4).value)
                
                with Pool(10) as p:
                    text = p.map(html_extract, raw)
                    
                d = pd.DataFrame({"title": title, "source": source, 
                                      "date": date, "text": text})
                
                for k in range(len(d.index)):
                    if d.loc[k, 'text'] == 0:
                        turl = worksheet.cell(row=i+k, column=5).value
                        if turl:
                            if 'http://' in turl:
                                tturl = re.sub('http://.*?/', '', turl, flags=re.DOTALL)
                                ttturl = turl.replace(tturl, '')
                                if ttturl not in urllist:
                                    count += 1
                                    urllist.append(ttturl)
                                    testlist.append(turl)
                                    print(count, turl)
                                    print('=======================================================================')
                            elif 'https://' in turl:
                                tturl = re.sub('https://.*?/', '', turl, flags=re.DOTALL)
                                ttturl = turl.replace(tturl, '')
                                if ttturl not in urllist:
                                    count += 1
                                    urllist.append(ttturl)
                                    testlist.append(turl)
                                    print(count, turl)
                                    print('=======================================================================')
                                
                            
                d = d[d.text != 0]
                
                for sheetname in writer.sheets:
                    d.to_excel(writer,sheet_name=sheetname, startrow=writer.sheets[sheetname].max_row, 
                               index = False,header= False)
                
            writer.save()
            #elapsed = (time.time() - start)  
            #print("\n","time elapsed is :", elapsed)
            #print('=======================================================================')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:277: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# 1 http://www.gukjenews.com/news/articleView.html?idxno=1047684
# =======================================================================
# 2 http://www.wikitree.co.kr/main/news_view.php?id=393558
# =======================================================================
# 3 http://www.nbnnews.co.kr/news/articleView.html?idxno=218288
# =======================================================================
# 4 http://www.topstarnews.net/news/articleView.html?idxno=558075
# =======================================================================
# 5 http://www.obsnews.co.kr/news/articleView.html?idxno=1134150
# =======================================================================
# 6 http://www.ilyosisa.co.kr/news/articleView.html?idxno=201838
# =======================================================================
# 7 http://www.fntoday.co.kr/news/articleView.html?idxno=176005
# =======================================================================
# 8 http://medipana.com/news/news_viewer.asp?NewsNum=232873&MainKind=A&NewsKind=5&vCount=12&vKind=1
# =======================================================================
# 9 http://www.joongdo.co.kr/main/view.php?key=20181231010012358
# =======================================================================
# 10 http://www.christiantoday.co.kr/news/318952
# =======================================================================
# 11 http://www.joongboo.com/news/articleView.html?idxno=1316189
# =======================================================================
# 12 http://www.kyeongin.com/main/view.php?key=20190101010000097
# =======================================================================
# 13 http://www.ksilbo.co.kr/news/articleView.html?idxno=675753
# =======================================================================
# 14 http://www.dkilbo.com/news/articleView.html?idxno=167259
# =======================================================================
# 15 http://www.idaegu.co.kr/news/articleView.html?idxno=266730
# =======================================================================
# 16 http://www.dynews.co.kr/news/articleView.html?idxno=437364
# =======================================================================
# 17 http://news.ebs.co.kr/ebsnews/allView/20009209/H
# =======================================================================
# 18 http://www.seoulwire.com/news/articleView.html?idxno=43142
# =======================================================================
# 19 http://www.dgmbc.com/new/news/view2.do?nav=news&selectedId=220259&class_code1=&news_cate=null
# =======================================================================
# 20 http://www.kyeonggi.com/news/articleView.html?idxno=2026945
# =======================================================================
# 21 http://www.ilyoseoul.co.kr/news/articleView.html?idxno=278069
# =======================================================================
# 22 http://www.sisaweek.com/news/articleView.html?idxno=117092
# =======================================================================
# 23 http://www.kbmaeil.com/news/articleView.html?idxno=802147
# =======================================================================
# 24 http://www.jjn.co.kr/news/articleView.html?idxno=762726
# =======================================================================
# 25 http://www.ggilbo.com/news/articleView.html?idxno=579758
# =======================================================================
# 26 http://www.slist.kr/news/articleView.html?idxno=59789
# =======================================================================
# 27 http://www.idaegu.com?c=2&uid=401650
# =======================================================================
# 28 http://www.newscj.com/news/articleView.html?idxno=587773
# =======================================================================
# 29 http://www.cctimes.kr/news/articleView.html?idxno=555433
# =======================================================================
# 30 http://www.gnmaeil.com/news/articleView.html?idxno=402817
# =======================================================================
# 31 http://www.honam.co.kr/read.php3?aid=1546340400573543021
# =======================================================================
# 32 http://www.jbnews.com/news/articleView.html?idxno=1230663
# =======================================================================
# 33 http://www.kgnews.co.kr/news/articleView.html?idxno=536544
# =======================================================================
# 34 http://www.econonews.co.kr/news/articleView.html?idxno=48347
# =======================================================================
# 35 http://www.kjdaily.com/read.php3?aid=1546337376457057002
# =======================================================================
# 36 http://www.newstown.co.kr/news/articleView.html?idxno=392876
# =======================================================================
# 37 http://www.mediaus.co.kr/news/articleView.html?idxno=142312
# =======================================================================
# 38 http://www.iusm.co.kr/news/articleView.html?idxno=830678
# =======================================================================
# 39 http://www.ccdn.co.kr/news/articleView.html?idxno=557062
# =======================================================================
# 40 http://www.g-enews.com/ko-kr/news/article/news_all/2019010118573178394e4869c120_1/article.html
# =======================================================================
# 41 http://www.monews.co.kr/news/articleView.html?idxno=123630
# =======================================================================
# 42 http://www.kbsm.net/default/index_view_page.php?idx=229201&part_idx=332
# =======================================================================
# 43 http://www.gwangnam.co.kr/read.php3?aid=1546335006315064015
# =======================================================================
# 44 http://www.newsworks.co.kr/news/articleView.html?idxno=323612
# =======================================================================
# 45 http://tvdaily.asiae.co.kr/read.php3?aid=15463337741426014002
# =======================================================================
# 46 http://www.sporbiz.co.kr/news/articleView.html?idxno=300727
# =======================================================================
# 47 http://www.jndn.com/article.php?aid=1546334030273843023
# =======================================================================
# 48 http://www.allurekorea.com/?p=95972
# =======================================================================
# 49 http://www.nspna.com/news/?mode=view&newsid=329179
# =======================================================================
# 50 http://www.dtnews24.com/news/articleView.html?idxno=534958
# =======================================================================
# 51 https://jnilbo.com/?p=782806
# =======================================================================
# 52 http://www.newsworker.co.kr/news/articleView.html?idxno=24541
# =======================================================================
# 53 http://www.sisamagazine.co.kr/news/articleView.html?idxno=166123
# =======================================================================
# 54 http://www.ajunews.com/view/20181228110118737
# =======================================================================
# 55 http://www.hidomin.com/news/articleView.html?idxno=376569
# =======================================================================
# 56 http://www.anewsa.com/detail.php?number=1459955&thread=03r02
# =======================================================================
# 57 http://www.cfnews.kr/news.aspx/19042
# =======================================================================
# 58 http://news.bbsi.co.kr/news/articleView.html?idxno=915583
# =======================================================================
# 59 http://www.kukinews.com/news/article.html?no=617822
# =======================================================================
# 60 http://www.sjbnews.com/news/articleView.html?idxno=625686
# =======================================================================
# 61 http://www.greened.kr/news/articleView.html?idxno=89137
# =======================================================================
# 62 http://www.viva100.com/main/view.php?key=20190101010000147
# =======================================================================
# 63 http://www.jeollailbo.com/news/articleView.html?idxno=558942
# =======================================================================
# 64 http://www.ccnnews.co.kr/news/articleView.html?idxno=135171
# =======================================================================
# 65 http://www.newsfc.co.kr/news/articleView.html?idxno=34782
# =======================================================================
# 66 http://www.shinailbo.co.kr/news/articleView.html?idxno=1130589
# =======================================================================
# 67 http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0500&key=20190101.99099000272
# =======================================================================
# 68 http://www.ihalla.com/read.php3?aid=1546326721617517322
# =======================================================================
# 69 http://www.idomin.com/?mod=news&act=articleView&idxno=585585
# =======================================================================
# 70 http://www.sportsq.co.kr/news/articleView.html?idxno=316459
# =======================================================================
# 71 https://www.huffingtonpost.kr/entry/story_kr_5c29d346e4b0407e908432e6?utm_id=naver
# =======================================================================
# 72 http://www.namdonews.com/news/articleView.html?idxno=504289
# =======================================================================
# 73 http://www.psnews.co.kr/news/article.html?no=22226
# =======================================================================
# 74 http://www.horsebiz.co.kr/hbns/new_hbns/index.phtml?mode=view_sisa&vcode=701001&view_id=20190000012
# =======================================================================
# 75 http://www.asiatoday.co.kr/view.php?key=20181231010018816
# =======================================================================
# 76 http://www.incheonilbo.com/news/articleView.html?idxno=921562
# =======================================================================
# 77 http://www.koreatimes.com/article/1222672
# =======================================================================
# 78 http://www.domin.co.kr/news/articleView.html?idxno=1224885
# =======================================================================
# 79 http://www.upkorea.net/news/articleView.html?idxno=462770
# =======================================================================
# 80 http://www.getnews.co.kr/view.php?ud=20190101150545114341d0c69529_16
# =======================================================================
# 81 http://www.metroseoul.co.kr/news/newsview?newscd=2019010100103
# =======================================================================
# 82 http://leaders.asiae.co.kr/news/articleView.html?idxno=83570
# =======================================================================
# 83 http://www.mdtoday.co.kr/mdtoday/index.html?no=342885
# =======================================================================
# 84 http://www.dtoday.co.kr/news/articleView.html?idxno=291089
# =======================================================================
# 85 http://www.greenpostkorea.co.kr/news/articleView.html?idxno=99886
# =======================================================================
# 86 http://www.ftoday.co.kr/news/articleView.html?idxno=105650
# =======================================================================
# 87 http://www.insightkorea.co.kr//news/articleView.html?idxno=33148
# =======================================================================
# 88 http://www.thegolftimes.co.kr/news/articleView.html?idxno=38354
# =======================================================================
# 89 http://www.kgdm.co.kr/news/articleView.html?idxno=620426
# =======================================================================
# 90 http://www.inews365.com/news/article.html?no=564781
# =======================================================================
# 91 http://www.idjnews.kr/news/articleView.html?idxno=47085
# =======================================================================
# 92 http://stoo.asiae.co.kr/article.php?aid=51928043027
# =======================================================================
# 93 http://kids.hankooki.com/lpage/news/201901/kd20190101140047125630.htm
# =======================================================================
# 94 http://www.tourtimes.net/sub_read.html?uid=61047§ion=sc56
# =======================================================================
# 95 http://www.jjan.kr/news/articleView.html?idxno=2028289
# =======================================================================
# 96 http://www.straightnews.co.kr/news/articleView.html?idxno=40432
# =======================================================================
# 97 http://www.kpinews.co.kr/news/articleView.html?idxno=86877
# =======================================================================
# 98 https://www.jnilbo.com/view/media/view?code=2019010113413914864
# =======================================================================
# 99 http://www.chungnamilbo.com/news/articleView.html?idxno=478819
# =======================================================================
# 100 http://weeklytrade.co.kr/news/view.html?section=1&category=160&item=&no=48383
# =======================================================================
# 101 http://www.pointn.net/news/articleView.html?idxno=2573
# =======================================================================
# 102 http://www.newstomato.com/ReadNews.aspx?no=866844
# =======================================================================
# 103 http://www.sisunnews.co.kr/news/articleView.html?idxno=94863
# =======================================================================
# 104 http://www.gyotongn.com/news/articleView.html?idxno=217629
# =======================================================================
# 105 http://daily.hankooki.com/lpage/politics/201901/dh20190101125737137490.htm
# =======================================================================
# 106 http://www.vop.co.kr/A00001366946.html
# =======================================================================
# 107 http://www.gobalnews.com/news/articleView.html?idxno=26719
# =======================================================================
# 108 http://www.newsrep.co.kr/news/articleView.html?idxno=61600
# =======================================================================
# 109 http://www.enewstoday.co.kr/news/articleView.html?idxno=1259130
# =======================================================================
# 110 http://www.digitaltoday.co.kr/news/articleView.html?idxno=205946
# =======================================================================
# 111 http://www.bosa.co.kr/news/articleView.html?idxno=2097103
# =======================================================================
# 112 http://www.breaknews.com/624741
# =======================================================================
# 113 http://www.electimes.com/article.php?aid=1546311857171480084
# =======================================================================
# 114 http://www.newskr.kr/news/articleView.html?idxno=16626
# =======================================================================
# 115 http://www.hg-times.com/news/articleView.html?idxno=196003
# =======================================================================
# 116 http://www.jemin.com/news/articleView.html?idxno=560211
# =======================================================================
# 117 http://www.upinews.kr/news/newsview.php?ncode=1065577876319197
# =======================================================================
# 118 http://www.speconomy.com/news/articleView.html?idxno=134394
# =======================================================================
# 119 http://www.00news.co.kr/news/articleView.html?idxno=56178
# =======================================================================
# 120 http://www.gokorea.kr/news/articleView.html?idxno=66207
# =======================================================================
# 121 http://www.bzeronews.com/news/articleView.html?idxno=381396
# =======================================================================
# 122 http://kpenews.com/Board.aspx?BoardNo=23868
# =======================================================================
# 123 http://munhaknews.com/?p=22267
# =======================================================================
# 124 http://news.maxmovie.com/390718
# =======================================================================
# 125 http://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2018123110251024989
# =======================================================================
# 126 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&oid=108&aid=0002751912
# =======================================================================
# 127 http://www.betanews.net:8080/article/954512.html
# =======================================================================
# 128 http://www.nbntv.co.kr/news/articleView.html?idxno=154071
# =======================================================================
# 129 http://www.koreadaily.com/news/read.asp?art_id=6860222
# =======================================================================
# 130 https://kizmom.hankyung.com/news/view.html?aid=201812318329o
# =======================================================================
# 131 http://www.legaltimes.co.kr/news/articleView.html?idxno=43811
# =======================================================================
# 132 http://www.futurekorea.co.kr/news/articleView.html?idxno=114058
# =======================================================================
# 133 http://nc.asiae.co.kr/view.htm?idxno=2018122915125932738
# =======================================================================
# 134 http://www.queen.co.kr/news/articleView.html?idxno=306590
# =======================================================================
# 135 http://famtimes.co.kr/news/view/93161
# =======================================================================
# 136 http://www.newsjeju.net/news/articleView.html?idxno=322874
# =======================================================================
# 137 http://www.e2news.com/news/articleView.html?idxno=205860
# =======================================================================
# 138 http://www.mjmedi.com/news/articleView.html?idxno=35996
# =======================================================================
# 139 http://www.econovill.com/news/articleView.html?idxno=353379
# =======================================================================
# 140 http://www.docdocdoc.co.kr/news/articleView.html?idxno=1063996
# =======================================================================
# 141 http://research-paper.co.kr/news/view/68164
# =======================================================================
# 142 http://www.medicaltimes.com/Users/News/NewsView.html?mode=view&ID=1123528&REFERER=NP
# =======================================================================
# 143 http://www.ebn.co.kr/news/view/967076
# =======================================================================
# 144 http://www.goodmorningcc.com/news/articleView.html?idxno=206142
# =======================================================================
# 145 http://www.gnnews.co.kr/news/articleView.html?idxno=346442
# =======================================================================
# 146 https://www.voakorea.com/a/4722937.html
# =======================================================================
# 147 http://sports.news.naver.com/general/news/read.nhn?oid=020&aid=0003190377
# =======================================================================
# 148 http://www.ikpnews.net/news/articleView.html?idxno=36240
# =======================================================================
# 149 http://www.babytimes.co.kr/news/articleView.html?idxno=24210
# =======================================================================
# 150 http://www.fintechpost.co.kr/news/articleView.html?idxno=13753
# =======================================================================
# 151 http://www.dailypharm.com/Users/News/NewsView.html?ID=248098&REFERER=NP
# =======================================================================
# 152 http://www.skyedaily.com/news/news_view.html?ID=80442
# =======================================================================
# 153 http://www.4th.kr/news/articleView.html?idxno=7773
# =======================================================================
# 154 http://www.theceluv.com/article.php?aid=1546271395229823009
# =======================================================================
# 155 http://www.kfm.co.kr/?r=home&m=blog&blog=news&front=list&uid=9331340
# =======================================================================
# 156 http://www.civicnews.com/news/articleView.html?idxno=19779
# =======================================================================
# 157 http://www.nongmin.com/article/ar_detail.htm?ar_id=293870
# =======================================================================
# 158 http://www.wikileaks-kr.org/news/articleView.html?idxno=44497
# =======================================================================
# 159 http://www.wsobi.com/news/articleView.html?idxno=68389
# =======================================================================
# 160 http://www.mygoyang.com/news/articleView.html?idxno=49487
# =======================================================================
# 161 http://www.ccdailynews.com/news/articleView.html?idxno=992487
# =======================================================================
# 162 http://www.youngnong.co.kr/news/articleView.html?idxno=20083
# =======================================================================
# 163 http://www.news-paper.co.kr/news/articleView.html?idxno=31850
# =======================================================================
# 164 http://www.usmbc.co.kr/news/detail.tc?mn=808&pageSeq=612&pageIndex=1&idx=190781
# =======================================================================
# 165 http://www.iminju.net/news/articleView.html?idxno=41748
# =======================================================================
# 166 http://news.unn.net/news/articleView.html?idxno=205424
# =======================================================================
# 167 http://www.tfnews.co.kr/news/article.html?no=58939
# =======================================================================
# 168 http://www.whitepaper.co.kr/news/articleView.html?idxno=136652
# =======================================================================
# 169 http://www.jejuilbo.net/news/articleView.html?idxno=111905
# =======================================================================
# 170 http://radio.ytn.co.kr/program/?f=2&id=59995&s_mcd=0263&s_hcd=01
# =======================================================================
# 171 http://www.joynews24.com/view/1149042
# =======================================================================
# 172 http://harpersbazaar.co.kr/?p=59225
# =======================================================================
# 173 http://www.businesspost.co.kr/BP?command=article_view&num=108618
# =======================================================================
# 174 http://www.joygm.com/news/articleView.html?idxno=17611
# =======================================================================
# 175 http://www.tongilnews.com/news/articleView.html?idxno=127402
# =======================================================================
# 176 http://www.newsnjoy.or.kr/news/articleView.html?idxno=221853
# =======================================================================
# 177 http://www.hdhy.co.kr/news/articleView.html?idxno=8765
# =======================================================================
# 178 http://www.marketnews.co.kr/view.php?ud=2019010219141697232d12411ff9_24
# =======================================================================
# 179 http://www.sisaon.co.kr/news/articleView.html?idxno=80965
# =======================================================================
# 180 http://www.gocj.net/news/articleView.html?idxno=99026
# =======================================================================
# 181 http://www.rapportian.com/news/articleView.html?idxno=115243
# =======================================================================
# 182 http://news.cjhello.com/news/newsView.do?soCode=SC40000000&idx=241281
# =======================================================================
# 183 http://www.ttlnews.com/article/KOREA/4821
# =======================================================================
# 184 http://ch1.tbroad.com/content/view?parent_no=24&content_no=61&p_no=72197
# =======================================================================
# 185 http://www.newsfreezone.co.kr/news/articleView.html?idxno=93846
# =======================================================================
# 186 http://www.beopbo.com/news/articleView.html?idxno=203438
# =======================================================================
# 187 http://www.techholic.co.kr/news/articleView.html?idxno=179955
# =======================================================================
# 188 http://www.ikld.kr/news/articleView.html?idxno=103684
# =======================================================================
# 189 http://www.dhnews.co.kr/news/articleView.html?idxno=90046
# =======================================================================
# 190 http://www.starseoultv.com/news/articleView.html?idxno=515901
# =======================================================================
# 191 http://www.epj.co.kr/news/articleView.html?idxno=21142
# =======================================================================
# 192 http://www.jejunews.com/news/articleView.html?idxno=2128689
# =======================================================================
# 193 http://www.wonnews.co.kr/news/articleView.html?idxno=202790
# =======================================================================
# 194 http://www.ntoday.co.kr/news/articleView.html?idxno=64809
# =======================================================================
# 195 http://www.veritas-a.com/news/articleView.html?idxno=139783
# =======================================================================
# 196 http://www.wolyo.co.kr/news/articleView.html?idxno=74978
# =======================================================================
# 197 http://www.gvalley.co.kr/562254
# =======================================================================
# 198 http://fpn119.co.kr/sub_read.html?uid=108980§ion=sc102
# =======================================================================
# 199 http://mbnmoney.mbn.co.kr/news/view?news_no=MM1003447910
# =======================================================================
# 200 http://www.doctorsnews.co.kr/news/articleView.html?idxno=127059
# =======================================================================
# 201 http://www.siminsori.com/news/articleView.html?idxno=206910
# =======================================================================
# 202 http://www.dailygrid.net/news/articleView.html?idxno=115982
# =======================================================================
# 203 http://bntnews.hankyung.com/apps/news?popup=0&nid=08&c1=08&c2=08&c3=00&nkey=201812271826283&mode=sub_view
# =======================================================================
# 204 http://www.cbinews.co.kr/news/articleView.html?idxno=126085
# =======================================================================
# 205 http://www.daejeontoday.com/news/articleView.html?idxno=530935
# =======================================================================
# 206 http://www.kyosu.net/news/articleView.html?idxno=43593
# =======================================================================
# 207 http://www.welfarenews.net/news/articleView.html?idxno=67229
# =======================================================================
# 208 http://www.lecturernews.com/news/articleView.html?idxno=12500
# =======================================================================
# 209 http://www.economytalk.kr/news/articleView.html?idxno=176657
# =======================================================================
# 210 http://www.stardailynews.co.kr/news/articleView.html?idxno=227833
# =======================================================================
# 211 http://sports.hankooki.com/lpage/entv/201901/sp20190102164457136690.htm
# =======================================================================
# 212 http://www.entermedia.co.kr/news/news_view.html?idx=9128
# =======================================================================
# 213 http://www.weeklytoday.com/news/articleView.html?idxno=70857
# =======================================================================
# 214 http://viewers.heraldcorp.com/news/articleView.html?idxno=25938
# =======================================================================
# 215 http://www.energydaily.co.kr/news/articleView.html?idxno=95792
# =======================================================================
# 216 http://www.ceopartners.co.kr/bbs/board.php?bo_table=bd_01&wr_id=117
# =======================================================================
# 217 http://www.apparelnews.co.kr/naver/view.php?iid=74380
# =======================================================================
# 218 http://ch.yes24.com/Article/View/37806
# =======================================================================
# 219 http://www.newsmin.co.kr/news/36286
# =======================================================================
# 220 http://www.issuemaker.kr/news/articleView.html?idxno=23583
# =======================================================================
# 221 http://www.catholicnews.co.kr/news/articleView.html?idxno=20826
# =======================================================================
# 222 http://www.updownnews.co.kr/news/articleView.html?idxno=101641
# =======================================================================
# 223 http://www.thescoop.co.kr/news/articleView.html?idxno=33281
# =======================================================================
# 224 http://jmagazine.joins.com/forbes/view/324265
# =======================================================================
# 225 http://www.thefirstmedia.net/news/articleView.html?idxno=45313
# =======================================================================
# 226 http://www.siminilbo.co.kr/news/articleView.html?idxno=595476
# =======================================================================
# 227 http://www.sisajournal-e.com/news/articleView.html?idxno=193556
# =======================================================================
# 228 http://www.newswatch.kr/news/articleView.html?idxno=16771
# =======================================================================
# 229 http://www.hemophilia.co.kr/news/articleView.html?idxno=7542
# =======================================================================
# 230 http://www.meconomynews.com/news/articleView.html?idxno=19366
# =======================================================================
# 231 http://www.k-health.com/news/articleView.html?idxno=41654
# =======================================================================
# 232 http://www.thebell.co.kr/front/free/contents/news/article_view.asp?key=201812310100048200002941
# =======================================================================
# 233 http://www.mediajeju.com/news/articleView.html?idxno=313574
# =======================================================================
# 234 http://www.readersnews.com/news/articleView.html?idxno=91489
# =======================================================================
# 235 http://www.rwn.co.kr/news/articleView.html?idxno=48106
# =======================================================================
# 236 http://www.knnews.co.kr/news/articleView.php?idxno=1272677
# =======================================================================
# 237 https://www.lawtimes.co.kr/Legal-News/Legal-News-View?serial=149742
# =======================================================================
# 238 http://www.businesskorea.co.kr/news/articleView.html?idxno=27931
# =======================================================================
# 239 http://www.sommeliertimes.com/news/articleView.html?idxno=11758
# =======================================================================
# 240 http://www.fetv.co.kr/news/article.html?no=18137
# =======================================================================
# 241 http://newsbrite.net/22246
# =======================================================================
# 242 http://www.newsfarm.co.kr/news/articleView.html?idxno=48727
# =======================================================================
# 243 http://www.dailysportshankook.co.kr/news/articleView.html?idxno=200708
# =======================================================================
# 244 http://www.ujnews.co.kr/news/articleView.html?idxno=436010
# =======================================================================
# 245 http://www.etoday.co.kr/news/section/newsview.php?idxno=1706426
# =======================================================================
# 246 http://news.einfomax.co.kr/news/articleView.html?idxno=4009832
# =======================================================================
# 247 http://www.choicenews.co.kr/news/articleView.html?idxno=47113
# =======================================================================
# 248 http://www.fsnews.co.kr/news/articleView.html?idxno=32154
# =======================================================================
# 249 http://www.kbanker.co.kr/news/articleView.html?idxno=77101
# =======================================================================
# 250 http://www.seoulfn.com/news/articleView.html?idxno=329655
# =======================================================================
# 251 http://www.kpanews.co.kr/article/show.asp?idx=200299&table=article&category=H
# =======================================================================
# 252 http://www.dailymedi.com/detail.php?number=838650&thread=22r02
# =======================================================================
# 253 http://www.inthenews.co.kr/news/article.html?no=12770
# =======================================================================
# 254 http://www.headlinejeju.co.kr/?mod=news&act=articleView&idxno=352339
# =======================================================================
# 255 http://www.ilemonde.com/news/articleView.html?idxno=10050
# =======================================================================
# 256 http://www.marieclairekorea.com/2019/01/fashion/%ec%9d%b4-%eb%aa%a8%eb%8d%b8%eb%93%a4%ec%9d%84-%ec%a3%bc%eb%aa%a9%ed%95%b4%ec%a3%bc%ec%84%b8%ec%9a%94/?_N_=01
# =======================================================================
# 257 http://www.visualdive.com/2019/01/%eb%b0%a4%ec%83%88-%ed%99%94%ec%9e%a5%ec%8b%a4%ec%97%90%ec%84%9c-%eb%b2%8c%ec%84%9c%eb%8d%98-4%ec%84%b8-%eb%94%b8-%ec%82%ac%eb%a7%9d-%ec%97%84%eb%a7%88-%ea%b8%b4%ea%b8%89%ec%b2%b4%ed%8f%ac/
# =======================================================================
# 258 http://www.gimhaenews.co.kr/news/articleView.html?idxno=25800
# =======================================================================
# 259 http://www.cpbc.co.kr/CMS/newspaper/view_body.php?cid=742867&path=201901
# =======================================================================
# 260 http://www.fashionbiz.co.kr/TN/?cate=2&recom=2&idx=170236
# =======================================================================
# 261 http://www.bokuennews.com/news/article.html?no=170179
# =======================================================================
# 262 http://www.areyou.co.kr/news/articleView.html?idxno=39478
# =======================================================================
# 263 http://www.foodnews.co.kr/news/articleView.html?idxno=68820
# =======================================================================
# 264 http://www.intn.co.kr/news/articleView.html?idxno=2003600
# =======================================================================
# 265 http://www.mediasr.co.kr/news/articleView.html?idxno=50559
# =======================================================================
# 266 http://lonelyplanet.co.kr/magazine/articles/AI_00002265
# =======================================================================
# 267 http://www.news2day.co.kr/117834
# =======================================================================
# 268 http://www.daejonilbo.com/news/newsitem.asp?pk_no=1350203
# =======================================================================
# 269 http://www.akomnews.com/?p=409034
# =======================================================================
# 270 http://www.hkbs.co.kr/news/articleView.html?idxno=495963
# =======================================================================
# 271 http://www.jejudomin.co.kr/news/articleView.html?idxno=108341
# =======================================================================
# 272 http://theleader.mt.co.kr/articleView.html?no=2019010210387825999
# =======================================================================
# 273 http://www.ilovepc.co.kr/news/articleView.html?idxno=21225
# =======================================================================
# 274 http://www.vogue.co.kr/?p=174046
# =======================================================================
# 275 http://www.taxtimes.co.kr/hous01.htm?r_id=238296
# =======================================================================
# 276 http://news.bookdb.co.kr/bdb/IssueStory.do?_method=detail&sc.webzNo=34905&Nnews
# =======================================================================
# 277 http://www.travie.com/news/articleView.html?idxno=20672
# =======================================================================
# 278 http://www.iloveorganic.co.kr/news/articleView.html?idxno=219716
# =======================================================================
# 279 http://www.sejungilbo.com/news/articleView.html?idxno=15193
# =======================================================================
# 280 http://www.datanet.co.kr/news/articleView.html?idxno=129925
# =======================================================================
# 281 http://www.ablenews.co.kr/News/NewsContent.aspx?CategoryCode=0034&NewsCode=003420190102092738641408
# =======================================================================
# 282 http://www.dandinews.com/news/articleView.html?idxno=4427
# =======================================================================
# 283 http://news.knn.co.kr/news/todaynews_read.asp?etime=2018122700061&userid=pyowill&newsgubun=society
# =======================================================================
# 284 http://www.cctvnews.co.kr/news/articleView.html?idxno=96988
# =======================================================================
# 285 http://www.yeongnam.com/mnews/newsview.do?mode=newsView&newskey=20190102.010210826430001
# =======================================================================
# 286 http://www.insnews.co.kr/design_php/news_view.php?num=56728&firstsec=2&secondsec=24
# =======================================================================
# 287 http://www.gndomin.com/news/articleView.html?idxno=191896
# =======================================================================
# 288 http://www.bizhankook.com/article/16910
# =======================================================================
# 289 https://platum.kr/archives/113851
# =======================================================================
# 290 http://www.labortoday.co.kr/news/articleView.html?idxno=155961
# =======================================================================
# 291 http://www.ksmnews.co.kr/default/index_view_page.php?idx=231300&part_idx=170
# =======================================================================
# 292 http://www.kado.net/?mod=news&act=articleView&idxno=946614
# =======================================================================
# 293 http://andongmbc.co.kr/adboard/NewsView36193
# =======================================================================
# 294 http://www.hellot.net/new_hellot/magazine/magazine_read.html?code=202&sub=004&idx=44399
# =======================================================================
# 295 http://www.itdaily.kr/news/articleView.html?idxno=92537
# =======================================================================
# 296 http://www.ujeil.com/news/articleView.html?idxno=223328
# =======================================================================
# 297 http://www.kjmbc.co.kr/board/index.cfm?bbs_name=todaynews&w=view&wr_id=235095
# =======================================================================
# 298 http://www.dailysmart.co.kr/news/articleView.html?idxno=4501
# =======================================================================
# 299 http://tjmbc.co.kr/000005/view/id/115915
# =======================================================================
# 300 http://www.cctoday.co.kr/?mod=news&act=articleView&idxno=1183455
# =======================================================================
# 301 http://www.tbc.co.kr/tbc_news/n14_newsview.html?p_no=20190103164332AE00242
# =======================================================================
# 302 http://www.ltn.kr/news/articleView.html?idxno=21392
# =======================================================================
# 303 http://www.cmbdj.co.kr/ab-991-13939
# =======================================================================
# 304 http://www.dailypop.kr/news/articleView.html?idxno=37125
# =======================================================================
# 305 http://cc.newdaily.co.kr/site/data/html/2019/01/03/2019010300186.html
# =======================================================================
# 306 http://www.srtimes.kr/news/articleView.html?idxno=30473
# =======================================================================
# 307 http://news.tongplus.com/site/data/html_dir/2019/01/03/2019010380124.html
# =======================================================================
# 308 http://www.jeonmin.co.kr/news/articleView.html?idxno=194706
# =======================================================================
# 309 https://jhealthmedia.joins.com/news/articleView.html?idxno=19959
# =======================================================================
# 310 http://www.interview365.com/news/articleView.html?idxno=83647
# =======================================================================
# 311 http://thetravelnews.co.kr/01/115605/
# =======================================================================
# 312 http://www.newsway.co.kr/news/view?tp=1&ud=2019010317174731619
# =======================================================================
# 313 http://gamefocus.co.kr/detail.php?number=89794
# =======================================================================
# 314 http://woman.donga.com/3/all/12/1595511/1
# =======================================================================
# 315 http://www.mediapen.com/news/view/405578
# =======================================================================
# 316 http://okfashion.co.kr/detail.php?number=51313&thread=81r09r01
# =======================================================================
# 317 http://www.youthdaily.co.kr/news/articleView.html?idxno=9011
# =======================================================================
# 318 http://www.constimes.co.kr/news/articleView.html?idxno=204139
# =======================================================================
# 319 http://kids.donga.com/news/vv.php?type=news&id=20190103162617288827
# =======================================================================
# 320 http://www.kyongbuk.co.kr/?mod=news&act=articleView&idxno=1049642
# =======================================================================
# 321 http://facttv.kr/facttvnews/detail.php?number=23348&thread=21r02
# =======================================================================
# 322 http://www.gametoc.co.kr/news/articleView.html?idxno=50400
# =======================================================================
# 323 http://www.newsprime.co.kr/news/article.html?no=442125
# =======================================================================
# 324 http://www.ktv.go.kr/content/view?content_id=567636
# =======================================================================
# 325 http://www.e-graphy.co.kr/news/articleView.html?idxno=3808
# =======================================================================
# 326 http://techm.kr/bbs/board.php?bo_table=article&wr_id=5468
# =======================================================================
# 327 http://www.it-b.co.kr/news/articleView.html?idxno=27049
# =======================================================================
# 328 http://www.hyunbulnews.com/news/articleView.html?idxno=298707
# =======================================================================
# 329 http://www.klnews.co.kr/news/articleView.html?idxno=118654
# =======================================================================
# 330 http://www.itnk.co.kr/news/articleView.html?idxno=59236
# =======================================================================
# 331 http://www.housingherald.co.kr/news/articleView.html?idxno=34028
# =======================================================================
# 332 http://www.todayenergy.kr/news/articleView.html?idxno=210195
# =======================================================================
# 333 http://www.opinionnews.co.kr/news/articleView.html?idxno=12758
# =======================================================================
# 334 http://zine.istyle24.com/Fashion/FashionView.aspx?Idx=41573&Menu=12&_C_=23069
# =======================================================================
# 335 http://www.farminsight.net/news/articleView.html?idxno=1384
# =======================================================================
# 336 http://www.hortitimes.com/news/articleView.html?idxno=9675
# =======================================================================
# 337 http://www.incheonnews.com/news/articleView.html?idxno=114781
# =======================================================================
# 338 http://monthly.chosun.com/client/mdaily/daily_view.asp?idx=5816&Newsnumb=2019015816
# =======================================================================
# 339 http://www.ccreview.co.kr/news/articleView.html?idxno=116552
# =======================================================================
# 340 http://www.gqkorea.co.kr/?p=133513
# =======================================================================
# 341 http://www.ezyeconomy.com/news/articleView.html?idxno=87433
# =======================================================================
# 342 http://www.koreahealthlog.com/news/articleView.html?idxno=22865
# =======================================================================
# 343 http://www.suhyupnews.co.kr/news/articleView.html?idxno=22499
# =======================================================================
# 344 http://www.busanmbc.co.kr/m01/m_0201.html?load=view&newsno=20190102003200000000T
# =======================================================================
# 345 http://www.venturesquare.net/772814
# =======================================================================
# 346 http://www.psychiatricnews.net/news/articleView.html?idxno=13449
# =======================================================================
# 347 http://kookbang.dema.mil.kr/newsWeb/20190103/9/BBSMSTR_000000010060/view.do
# =======================================================================
# 348 http://ilyo.co.kr/?ac=article_view&entry_id=321342
# =======================================================================
# 349 http://www.ktnews.com/sub/view.php?cd_news=109345
# =======================================================================
# 350 http://esquirekorea.co.kr/?p=42900
# =======================================================================
# 351 http://www.yonhapmidas.com/article/190104194601_479668
# =======================================================================
# 352 http://www.laborplus.co.kr/news/articleView.html?idxno=21117
# ...
# 561 http://atiika.com/news/view/519
# =======================================================================
# 562 http://www.suwon.com/news/articleView.html?idxno=132151
# =======================================================================
# 563 http://www.suwonilbo.kr/news/articleView.html?idxno=132192
# =======================================================================
# 564 http://www.cooknchefnews.com/news/newsview.php?ncode=1065569191385417
# =======================================================================
# 565 https://www.bbc.com/korean/international-48306943?xtor=AL-[73]-[partner]-[naver]-[headline]-[korean]-[bizdev]-[isapi]
# =======================================================================
# 566 https://ysmbc.co.kr/article/0hqqIVhrWV
# =======================================================================
# 567 http://www.newsgn.com/250878
# =======================================================================
# 568 http://www.thedrive.co.kr/news/newsview.php?ncode=1065576640185259
# =======================================================================
# 569 https://chmbc.co.kr/article/iWIGh-s3tj3
# =======================================================================
# 570 https://news.kjmbc.co.kr/node/295309
# =======================================================================
# 571 http://www.webdaily.co.kr/view.php?ud=2019060116534280567b682bb492_7
# =======================================================================
# 572 http://www.jibs.co.kr/news/replay/viewNewsReplayDetail/2019060303432998782?feed=na
# =======================================================================
# 573 http://nbntv.co.kr/news/view/400599
# =======================================================================
# 574 http://koreajoongangdaily.joins.com/news/article/article.aspx?aid=3064208
# =======================================================================
# 575 http://www.netongs.com/news/articleView.html?idxno=200554
# =======================================================================
# 576 https://www.wikitree.co.kr/main/news_view.php?id=437484
# =======================================================================
# 577 http://www.paxnetnews.com/articles/49789
# =======================================================================
# 578 https://www.paxnetnews.com/articles/49894
# =======================================================================
# 579 http://www.cmbkj.co.kr/ab-991-12767
# =======================================================================
# 580 http://www.ceoscoredaily.com/news/article.html?no=56959
# =======================================================================
# 581 https://www.vop.co.kr/A00001416990.html
# =======================================================================
# 582 http://medicalworldnews.co.kr/news/view.php?idx=1510931409
# =======================================================================
# 583 https://www.horsebiz.co.kr/news/articleView.html?idxno=35117
# =======================================================================
# 584 https://jejumbc.com/article/pU7sWYEPgHDMdR
# =======================================================================
# 585 http://inthenews.co.kr/article-5031/
# =======================================================================
# 586 http://www.fashionn.com/board/read_new.php?table=1025&number=29317
# =======================================================================
# 587 http://www.startuptoday.kr/news/articleView.html?idxno=26223
# =======================================================================
# 588 http://www.yakup.com/news/index.html?mode=view&cat=14&nid=232926
# =======================================================================
# 589 https://www.venturesquare.net/786479
# =======================================================================
# 590 http://aitimes.co.kr/news/view/83897
# =======================================================================
# 591 http://www.ciobiz.co.kr/news/article.html?id=20190724120002
# =======================================================================
# 592 http://www.hidoc.co.kr/healthstory/news/C0000472296
# =======================================================================
# 593 http://www.golfguide.co.kr/news/articleView.html?idxno=13958
# =======================================================================
# 594 https://www.artinsight.co.kr/news/view.php?no=42918
# =======================================================================
# 595 http://bit.ly/2K4vdPv
# =======================================================================
# 596 http://www.consumernews.co.kr/?mod=news&act=articleView&idxno=532748
# =======================================================================
# 597 http://www.thegames.co.kr/news/articleView.html?idxno=213626
# =======================================================================
# 598 http://www.newshankuk.com/news/content.asp?news_idx=201907251246230104
# =======================================================================
# 599 http://www.dailyvet.co.kr/news/policy/116845
# =======================================================================
# 600 http://kdfnews.com/news/view.php?idx=34735
# =======================================================================
# 601 http://www.lawissue.co.kr/view.php?ud=2019073116101769089a8c8bf58f_12
# =======================================================================
# 602 http://www.harpersbazaar.co.kr/article/40392
# =======================================================================
# 603 http://fn.segye.com/content/html/2019/08/02/20190802506680.html?OutUrl=naver
# =======================================================================
# 604 http://economychosun.com/client/news/view.php?boardName=C26&t_num=13607499
# =======================================================================
# 605 https://www.insight.co.kr/news/240651
# =======================================================================
# 606 http://siminilbo.co.kr/news/newsview.php?ncode=1065565379112476
# =======================================================================
# 607 http://www.ddanzi.com/571024744
# =======================================================================
# 608 http://thegear.kr/17384
# =======================================================================
# 609 http://it.chosun.com/site/data/html_dir/2019/08/20/2019082002230.html
# =======================================================================
# 610 http://www.esquirekorea.co.kr/article/41788
# =======================================================================
# 611 http://www.cristiantoday.co.kr/news/324928
# =======================================================================
# 612 http://www.thegear.kr/news/articleView.html?idxno=20054
# =======================================================================
# 613 http://www.danbinews.com/news/articleView.html?idxno=12146
# =======================================================================
# 614 http://www.thedailypost.kr/news/articleView.html?idxno=70348
# =======================================================================
# 615 http://www.dizzotv.com/site/data/html_dir/2019/09/04/2019090480052.html
# =======================================================================
# 616 http://www.rank5.kr/news/articleView.html?idxno=5487
# =======================================================================
# 617 https://www.ksg.co.kr/news/main_newsView.jsp?pNum=123389
# =======================================================================
# 618 http://www.dailybizon.com/news/articleView.html?idxno=13741
# =======================================================================
# 619 https://slownews.kr/74225
# =======================================================================
# 620 http://www.seouleconews.com/news/articleView.html?idxno=51408
# =======================================================================
# 621 http://www.gameshot.net/common/con_view.php?code=GA5d81b569a80e9
# =======================================================================
# 622 https://www.golfjournal.co.kr/news/articleView.html?idxno=1847
# =======================================================================
# 623 http://www.megaeconomy.co.kr/news/articleView.html?idxno=92048
# =======================================================================
# 624 http://www.lawleader.co.kr/news/articleView.html?idxno=3113
# =======================================================================
# 625 http://www.womaneconomy.kr/news/articleView.html?idxno=81034
# =======================================================================
# 626 http://www.cbci.co.kr/news/articleView.html?idxno=327484
# =======================================================================
# 627 http://www.hyunchuk.co.kr/news/8771
# =======================================================================
# 628 http://www.globalmakers.co.kr/view.php?ud=201909300912512649d3244b4fed_39
# =======================================================================
# 629 http://www.newsclaim.co.kr/news/articleView.html?idxno=2085
# =======================================================================
# 630 http://www.lcnews.co.kr/news/articleView.html?idxno=1257
# =======================================================================
# 631 https://www.christiantoday.co.kr/news/325764
# =======================================================================
# 632 http://www.efnews.co.kr/news/articleView.html?idxno=81176
# =======================================================================
# 633 http://www.maeilnews.co.kr/news/article.html?no=5160
# =======================================================================
# 634 http://www.newslock.co.kr/news/articleView.html?idxno=21850
# =======================================================================
# 635 http://www.imwood.co.kr/news/articleView.html?idxno=23483
# =======================================================================
# 636 http://www.thekpm.com/view.php?ud=20191004160736385048e3dd6dd5_17
# =======================================================================
# 637 http://www.newstnt.com/news/articleView.html?idxno=38765
# =======================================================================
# 638 http://www.consumuch.com/news/articleView.html?idxno=46085
# =======================================================================
# 639 http://www.aitimes.com/news/articleView.html?idxno=120085
# =======================================================================
# 640 http://www.mediawatch.kr/news/article.html?no=254353
# =======================================================================
# 641 http://www.sjsori.com/news/articleView.html?idxno=39980
# =======================================================================
# 642 http://realty.chosun.com/site/data/html_dir/2019/10/13/2019101300783.html
# =======================================================================
# 643 http://coinreaders.com/5677
# =======================================================================
# 644 http://www.kdfnews.com/news/articleView.html?idxno=40023
# =======================================================================
# 645 http://www.mrepublic.co.kr/news/articleView.html?idxno=41073
# =======================================================================
# 646 http://www.tfmedia.co.kr/news/article.html?no=74761
# =======================================================================
# 647 https://www.g1tv.co.kr/index.php?type=news820&page=1&nth=0&viewNum=214742
# =======================================================================
# 648 http://www.pennmike.com/news/articleView.html?idxno=23880
# =======================================================================
# 649 https://asiatime.co.kr/news/newsview.php?ncode=1065600217048108
# =======================================================================
# 650 https://www.asiatime.co.kr/news/newsview.php?ncode=1065577660696863
# =======================================================================
# 651 http://www.newdaily.co.kr/news/article.html?no=91619
# =======================================================================
# 652 http://www.thereport.co.kr/news/articleView.html?idxno=6328
# =======================================================================
# 653 https://www.chuksannews.co.kr/news/article.html?no=219944
# =======================================================================
# 654 http://www.kmaeil.com/news/articleView.html?idxno=202708
# =======================================================================
# 655 http://www.kdpress.co.kr/news/articleView.html?idxno=93375
# =======================================================================
# 656 http://www.newsian.co.kr/news/articleView.html?idxno=37339
# =======================================================================
# 657 http://www.worktoday.co.kr/news/articleView.html?idxno=5023
# =======================================================================
# 658 http://news.inochong.org/detail.php?number=1945&thread=22r13
# =======================================================================
# 659 http://www.paxetv.com/news/articleView.html?idxno=81630
# =======================================================================
# 660 http://www.audioht.co.kr/news/articleView.html?idxno=10196
# =======================================================================
# 661 https://www.tfmedia.co.kr/news/article.html?no=76008
# =======================================================================
# 662 http://www.koreastocknews.com/news/articleView.html?idxno=48176
# =======================================================================
# 663 https://ditoday.com/%ec%b5%9c%ec%9b%90%ec%a4%80-%ed%8e%91%ed%83%80%ec%9d%b4-%ec%bd%94%eb%a6%ac%ec%95%84-%eb%8c%80%ed%91%9c/
# =======================================================================
# 664 http://news.appstory.co.kr/plan12494
# =======================================================================
# 665 http://mbcgn.kr/mbcgnnews/52992
# =======================================================================
# 666 http://www.safetimes.co.kr/news/articleView.html?idxno=78198
# =======================================================================
# 667 https://www.sisa-news.com/news/article.html?no=122338
# =======================================================================
# 668 https://www.inews365.com/news/article.html?no=603173
# =======================================================================
# 669 http://www.press9.kr/news/articleView.html?idxno=40622
# =======================================================================
# 670 http://www.epnc.co.kr/news/articleView.html?idxno=92919
# =======================================================================
# 671 http://www.asiaarts.net/view.php?ud=201912111107357491992c130dbe_38
# =======================================================================
# 672 http://www.globale.co.kr/view.php?ud=2019121314004282528743e6153c_36
# =======================================================================
# 673 https://www.mediapia.co.kr/news/articleView.html?idxno=63753
# =======================================================================
# 674 https://www.cts.tv/mission300/detail_mission/411/2266
# =======================================================================
# 675 https://www.maeilnews.co.kr/news/article.html?no=7497
# =======================================================================
# 676 http://www.natv.go.kr/renew09/brd/news/news_vw.jsp?newsId=44062
# =======================================================================
# 677 https://www.news2day.co.kr/145184
# =======================================================================
# 678 http://www.nongup.net/news/articleView.html?idxno=21860
# =======================================================================
# 679 http://4th.kr/View.aspx?No=639559
# =======================================================================
# 680 https://www.jejutwn.com/news/article.html?no=75028
# =======================================================================
# 681 http://www.thebigdata.co.kr/view.php?ud=201912312014257935e91b94b033_23
# =======================================================================

# %%
import requests
from bs4 import BeautifulSoup

olist = ['div#article-view-content-div', 'article#article-view-content-div', 'div.vcon_con', 'div#textBody', 'div.view_txt', 
            'div.article.detailCont', 'div.cont_cont', 'td.view_r', 'div#articleText', 'div.txtBox', 'section#ndArtBody, div#post-content', 
            '#main_content', 'div#textinput', 'div.rns_text', 'div.view_cnt', 'div#viewConts', 'div.news_contents', 'div#news_body_area', 
            'div#newsContents', 'div#content', 'div.vcon_in.articleContent', 'div.contentView', 'div#content_body', 'div#view_content', 
            'div#article', 'div.txt_article', 'div.article_body', 'div.content_print', 'td#ct', 'div#article_body', 'div.bodyarea', 'div.editor_area', 
            'div#news_body_id', '#container > div.con_left > div.view_left_warp > div.left_text_box', 'div#act-newsbody', 'div#print_arti',
            'div[itemprop="articleBody"]', 'div#articleBody', '.vcon_con_intxt', 'div#_article', 'div.article-news-body', 'div.read', '.cont-body', 
            'div#CmAdContent', '#news_contents', 'section.nd-news-body', 'div#fontSzArea', 'div#font', 'div.entry-content', 'div.article', 
            'div.news_content', 'div.col-12', '#CLtag', '#__newsBody__', 'div.viewConts', '.news_bm', 'div.news_article', '.rns_text', '#divContentViewBox', 
            '.wikitree_content', '.content', '.tipro', 'div.article-body', '#newsContent', '#news_content', '.view_article', '#content', '.PhotoBox', 
            'div.article_txt', 'article.contents-txt', '#fade_ad_postion', 'div#reportDetail', '#d_content', '.ContentCss', '.par', '.text', '.newscon', 
            'div.cnt_view.news_body_area', '.cont', 'div.float-right', 'div.newsContents', '.view_cont', 'span.news_text', '.news_con', 'div#GS_Content', 
            'div.view_body', 'div.col-xs-12', '.article__body', 'iv.smartOutput', 'div.cont-body', 'div.contents', '#txt_area', 
            '.contents-wrap', '#container > div.inner > div.section > div.article_view > div.article_content', 
            '#container > div.section_main > div.section > div > div.article > div > div, body > div.con > div.wrap2.tp2 > div.wr2_lt > div.v1d > div.v1d_con > div > div', 
            '#article-view-content-div', '#articleBody > div.conts, #newsView > div.rb-blog-body.rb-article', 
            '#viewForm > div.media_area > div.media_body > div.text, #wrapper > div.sub-container > div.sub-layout > div.cont-article > article > div > div.cont-area', 
            'div.newsTxt', 'body > div.vcon > div.vcon_in > div.v_lt > div > div.mi_lt > div.v1d > div.vtxt.detailCont', 
            '#article-view-content-div > div.cont-body > div:nth-child(1)', 'div.news-article-memo']

# %%
url = 'url'
raw = requests.get(url, headers={'User-Agent':'Mozilla/5.0'})
html = BeautifulSoup(raw.text, "lxml")

if '다.' in raw:
    tag = '태그'
    text = html.select_one(tag)
    print(text)

# %%
if tag not in olist:
    urllist.append(tag)
