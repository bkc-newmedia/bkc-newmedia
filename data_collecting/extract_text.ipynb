# %%
#날짜 빈 곳 채워야 함. 
import os
import re
import openpyxl
from bs4 import BeautifulSoup
import html2text

xlsx_name = os.path.join(os.path.dirname(os.getcwd()), 'xlsx_data', '#1_2019_여성', '{}.xlsx'.format("#1_"+"20190110"+"_여성"))
myworkbook=openpyxl.load_workbook(xlsx_name)
worksheet= myworkbook.get_sheet_by_name('Sheet')
print(worksheet.max_row)
# Out:
# 3237
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   # Remove the CWD from sys.path while we load stuff.

# %%
# 나중에 많이 짧은 뉴스는 생략하기. 

def nv_article(html):
    
    text = html.select_one("div#articleBodyContents")
    if not text:
        text = html.select_one("div#articeBody")
        
    if text:
        text = text.text
        text = text.replace('// flash 오류를 우회하기 위한 함수 추가', '').replace('function _flash_removeCallback() {}', '')
        text = text.replace('사진=연합뉴스TV[헤럴드경제=모바일섹션]', '').replace('=', '').replace('사진제공연합뉴스', '')
        text = text.replace('동영상 뉴스', '').replace('사진연합뉴스', '').replace('/AP연합뉴스', '').replace('/AP 연합뉴스', '')
        text = text.replace('사진제공', '').replace('ⓒ', '').replace('출처 AP 뉴시스', '').replace('©', '').replace('@', '')
        text = text.replace('삽화', '').replace('mtkhtyna.co.kr', '').replace('logosyna.co.kr', '').replace('changhani.co.kr', '')
        text = text.replace('ryousantayna.co.kr', '').replace('wooimaeil.com', '').replace('/연합뉴스', '').replace('/뉴시스', '')
        text = text.replace('/퍼스퍼코리아', '').replace('/CICI', '').replace('kjh9326newsis.com', '').replace('제공|스포티비뉴스', '')
        text = text.replace('검찰 로고/뉴스1', '').replace('photonewsis.com', '').replace('photonewsis.com', '')
        text = text.replace('<<시각장애인 음성정보 지원을 위한 텍스트입니다>>', '').replace('/사진', '').replace('게티이미지뱅크 제공', '')
        text = text.replace('/뉴스1', '').replace('<저작권자 공감언론 뉴시스통신사. 무단전재-재배포 금지.>', '').replace('unsplash ', '')
        text = text.replace('kknphotokyunghyang.com', '').replace('SBS방송 캡처.', '').replace('사진게티이미지뱅크', '')
        text = text.replace('게티이미지 제공', '').replace('신한금융지주 제공', '').replace('사진pixabay', '').replace('ppkjmnewsis.com', '')
        text = text.replace('|연합뉴스', '').replace('photoyna.co.kr', '').replace('동아닷컴DB', '').replace('News1', '')
        text = text.replace('superdoo82yna.co.kr', '').replace('padoseoul.co.kr', '').replace('자료제공', '').replace('출처 :', '')
        text = text.replace('hjmnewsis.com', '').replace('pak7130newsis.com', '').replace('myjsnewsis.com', '').replace('twopeoplehankyung.com', '')
        text = text.replace('모바일한경은 프리미엄 채널입니다.', '').replace('뉴시스', '').replace('dooleekyunghyang.com', '')
        text = text.replace('사진｜Gettyimages이매진스', '').replace('* 아래 텍스트는 실제 방송 내용과 차이가 있을 수 있으니 보다 정확한 내용은 방송으로 확인해주시기 바랍니다.', '')
        text = text.replace('퍼스트  언론,  <한겨레21>  정기구독으로  응원하기!  전화신청▶ 1566-9595 인터넷신청▶   http://bit.ly/1HZ0DmD카톡 선물하기▶  http://bit.ly/1UELpok  공식 SNS   Copyrights  한겨레신문사, 무단전재 및 재배포 금지<한겨레는 한국온라인신문협회의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.', '')
        text = text.replace('psykimsyna.co.kr', '').replace('사진동아일보 DB', '').replace('사진SBS캡쳐', '').replace('CBS노컷뉴스', '')
        text = text.replace('/VAST엔터테인먼트', '').replace('사진동아일보DB', '')
        text = text.replace('※은 일상 생활에서 겪은 황당한 이야기나 어이없는 갑질 등을 고발하는 코너입니다. 다른 독자들과 공유하고 싶은 사연이 있다면 보내주세요. 그중 채택해 에서 다루고 전문가 조언도 들어봅니다. 여러분의 사연을 보내실 곳은 jebohankyung.com입니다.', '')
        text = text.replace('게티이미지뱅크', '').replace('News', '').replace('이미지투데이', '').replace('jyaseoul.co.kr', '')
        text = text.replace('daunsoseoul.co.kr', '').replace('yohandonga.com', '')

        text = re.sub('사진.*?제공','', text, flags=re.DOTALL)
        text = re.sub('사진.*?인스타그램','', text, flags=re.DOTALL)
        text = re.sub('【.*】','',text)
        text = re.sub(r'[\(\[].*?[\)\]]', '', text)
        text = text.replace(']', '')

        try: 
            text = text[:text.rindex('다.')+2]
            return text
        except:
            return 0
    else:
        return 0
    
    

def etc_article(html):
    
    text = html.select_one('div#article-view-content-div')
    
    if not text:
        text = html.select_one('article#article-view-content-div')
        if not text:
            text = html.select_one('div#vcon_con articleContent detailCont')
    if text:
        text = text.text
        text = text.replace("▶디지털 뉴스콘텐츠 이용규칙 보기", "").replace("저작권자 © 기호일보 무단전재 및 재배포 금지", "")
        text = text.replace(').push', '').replace('사진=연합뉴스', '')
        text = "\n".join(text.split("\n"))
        text = text.rstrip('\n')
        text = re.sub(r'[\(\[].*?[\)\]]', '', text)
        text = re.sub('#.*?}','', text, flags=re.DOTALL)
        try:
            text = text[:text.rindex('다.')+2]
            return text
        except:
            return 0
    else:
        plist = html.select('p')
        text = [t.text for t in plist]
        text = ' '.join(text)
        text = text.replace('독자와 공감을 통해 더 나은 내일을 만들겠습니다.', '')
        text = re.sub(r'[\(\[].*?[\)\]]', '', text)
        text = re.sub('댓글.*?제한됩니다.','', text, flags=re.DOTALL)
        text = re.sub('【.*?】','',text)
        text = re.sub('베이비뉴스.*?쓰겠습니다.', '', text, flags=re.DOTALL)
        text = re.sub('글 =.*?있습니다.', '', text, flags=re.DOTALL)
        try:
            text = text[:text.rindex('다.')+2]
            return text
        except:
            return 0

tlist = list()
count = 0
for i in range(1, worksheet.max_row):
    raw = worksheet.cell(row=i, column=4).value
    
    if raw:
        html = BeautifulSoup(raw, "html.parser")
        text = nv_article(html)
        
        if not text: #여기에 네이버 외에 다른 기사 파일 정리
            if 'moved' in raw:
                url = html.find('a').get('href')
                try:
                    raw2 = requests.get(url, headers={'User-Agent':'Mozilla/5.0'})
                except:
                    continue
                
                html2 = BeautifulSoup(raw2.text, "html.parser")
                if 'naver' in url:
                    text = nv_article(html2)
                else:
                    text = etc_article(html2)
                
            elif '다.' in raw:
                url = worksheet.cell(row=i, column=5).value
# 179 http://it.chosun.com/site/data/html_dir/2019/01/10/2019011001000.html
# 180 http://www.cpbc.co.kr/CMS/newspaper/view_body.php?cid=743653&path=201901
# 181 http://www.sisaon.co.kr/news/articleView.html?idxno=81219
# 182 http://www.welfarenews.net/news/articleView.html?idxno=67282
# 183 http://www.00news.co.kr/news/articleView.html?idxno=56334
# 184 http://www.outsourcing.co.kr/news/articleView.html?idxno=83715
# 185 http://woman.chosun.com/client/news/viw.asp?cate=C01&mcate=M1002&nNewsNumb=20190161017
# 186 http://www.travelitoday.com/read/contentsView/1417/41
# 187 http://www.ccreview.co.kr/news/articleView.html?idxno=116616
# 188 http://www.kidd.co.kr/news/206642
# 189 http://www.newsworker.co.kr/news/articleView.html?idxno=24903
# 190 https://www.kfm.co.kr/?r=home&m=blog&blog=news&front=list&uid=9331898
# 191 http://monthly.chosun.com/client/mdaily/daily_view.asp?idx=5886&Newsnumb=2019015886
# 192 http://www.gndomin.com/news/articleView.html?idxno=192569
# 193 http://www.koreatimes.com/article/1224309
# 194 http://www.ksmnews.co.kr/default/index_view_page.php?idx=232134&part_idx=289
# 195 http://www.speconomy.com/news/articleView.html?idxno=135576
# 196 http://www.gnnews.co.kr/news/articleView.html?idxno=400375
# 197 http://www.redian.org/archive/128807
# 198 http://www.ujeil.com/news/articleView.html?idxno=223622
# 199 https://www.jungle.co.kr/magazine/200688
# 200 http://www.hidomin.com/news/articleView.html?idxno=377290
# 200

# %%
def etc_article(html):

    text = html.select_one('div#article-view-content-div')

    if not text:
        text = html.select_one('article#article-view-content-div')
        if not text:
            text = html.select_one('div.vcon_con')
            if not text:
                text = html.select_one('div#textBody')
                if not text:
                    text = html.select_one('div.view_txt')
                    if not text:
                        text = html.select_one('div.article.detailCont')
                        if not text:
                            text = html.select_one('div.cont_cont')
                            if not text:
                                text = html.select_one('td.view_r')
                                if not text:
                                    text = html.select_one('div#articleText')
                                    if not text:
                                        text = html.select_one('div#article')
                                        if not text:
                                            text = html.select_one('section#ndArtBody')
                                            if not text:
                                                text = html.select_one('div#post-content')
                                                if not text:
                                                    text = html.select_one('div#textinput')
                                                    if not text:
                                                        text = html.select_one('div.rns_text')
                                                        if not text:
                                                            text = html.select_one('div.view_cnt')
                                        
    if text:
        text = text.text
        text = text.replace("▶디지털 뉴스콘텐츠 이용규칙 보기", "").replace("저작권자 © 기호일보 무단전재 및 재배포 금지", "")
        text = text.replace(').push', '').replace('사진=연합뉴스', '').replace('/ TV조선 방송화면 캡처', '').replace('사진=뉴스1 제공', '')
        text = text.replace('사진출처: 온라인 커뮤니티', '').replace('/연합뉴스/', '').replace('▲ SBS <8뉴스> 화면 갈무리 ⓒ SBS', '')
        text = text.replace('< 경남신문의 콘텐츠는 저작권법의 보호를 받는 바, 무단전재·복사·재배포를 금합니다.', '').replace('ⓒ뉴시스', '')
        text = text.replace('기자의 다른 기사 보기', '').replace('◀ＥＮＤ▶', '')
        text = "\n".join(text.split("\n"))
        text = text.rstrip('\n')
        text = re.sub('저작권자 © 금강일보.*?있습니다.', '', text, flags=re.DOTALL)
        text = re.sub(r'[\(\[].*?[\)\]]', '', text)
        text = re.sub('#.*?}','', text, flags=re.DOTALL)
        text = re.sub('{.*?}','', text, flags=re.DOTALL)
        text = re.sub('사진=.*?엔터테인먼트', '',text, flags=re.DOTALL)
        text = re.sub('사진=.*?캡쳐', '',text, flags=re.DOTALL)
        text = re.sub('사진=.*?DB', '',text, flags=re.DOTALL)
        text = re.sub('사진출처=.*?캡처', '',text, flags=re.DOTALL)
        text = re.sub(';.*?;', '', text, flags=re.DOTALL)
        text = text.replace(';try;f.appendChild}catch});', '')
        try:
            text = text[:text.rindex('다.')+2]
            return text
        except:
            return 0
        
    else:
        print('hey')
        plist = html.select('p')
        text = [t.text for t in plist]
        text = ' '.join(text)
        text = text.replace('독자와 공감을 통해 더 나은 내일을 만들겠습니다.', '')
        text = text.replace('여러분의 제보가 세상을 바꿀 수 있습니다. 세상을 건강하게 변화시키는 인사이트의 수많은 기사들은 여러분의 제보로부터 시작됩니다.', '')
        text = text.replace('당사의 허락없이 본 기사와 사진의 무단 전재 및 재배포를 금합니다.', '')
        text = re.sub(r'[\(\[].*?[\)\]]', '', text)
        text = re.sub('댓글.*?제한됩니다.','', text, flags=re.DOTALL)
        text = re.sub('【.*?】','',text)
        text = re.sub('베이비뉴스.*?쓰겠습니다.', '', text, flags=re.DOTALL)
        text = re.sub('글 =.*?있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('전체보기 산업.*?입력', '', text, flags=re.DOTALL)
        text = re.sub('해당 언론사가.*?질 수 있습니다.', '', text, flags=re.DOTALL)
        text = re.sub('NSP통신/NSP.*?않습니다.', '', text, flags=re.DOTALL)
        try:
            text = text[:text.rindex('다.')+2]
            return text
        except:
            return 0
        
        
#년도 시간 형식 데이터만 지울 수 있는지 확인해보기
import requests
from bs4 import BeautifulSoup
import html2text
import re 
url =  "http://www.ktv.go.kr/content/view?content_id=568108"
raw = requests.get(url, headers={'User-Agent':'Mozilla/5.0'})
html = BeautifulSoup(raw.text, "lxml")
text = etc_article(html)
print(url)
print(text)
# Out:
# http://www.ktv.go.kr/content/view?content_id=568108
#
#
# 				신경은 앵커>
# 뉴스의 빈틈을 채워드리는 시간, 뉴스링크 시작합니다.
# 문재인 대통령이 오늘 신년 기자회견을 했습니다.
# 문 대통령은 '한국형 실업부조' 제도를 마련해 고용 안전망을 촘촘하게 짜겠다고 밝혔는데요.
# '실업부조'가 무엇인지, 뉴스링크에서 짚어봤습니다.
#
# 3. 실업부조
# '실업부조'는 실업자에게 급여를 지급해 구직을 돕는 제도인데요.
# 실업 급여 수급 자격이 없으면서, 국민기초생활 보장 제도 생계 급여를 받지 않는 실업자에게 지원되고요.
# 경력단절 여성과 취업과 실업을 반복하는 고용 불안정 근로자까지 포함됩니다.
# 취업지원 프로그램을 성실하게 이행한 참여자를 대상으로, 매달 50만원씩 최대 6개월간 수당이 지급됩니다.
# 정부는 이런 방안을 담은 '한국형 실업부조'를 2020년 시행한다는 계획인데요.
# '실업부조'가 고용 사각지대에 있던 실업자들에게 큰 힘이 되길 기대합니다.
#
# 교통사고 사망자의 3.6배.
# 지난해 기준 만 8천여명.
# 돌연사로 인한 사망자 숫자인데요.
# 요즘같은 때 돌연사 위험이 높다고합니다.
#
# 2. 돌연사
# '급성 심장 정지'로 인한 돌연사.
# 특히 날씨가 추워지는 겨울철에 조심해야하는데요.
# 따뜻한 실내에서 밖으로 나오면 주변 온도 영향으로 혈관이 수축합니다.
# 그런데 심장 동맥이 좁아지면, 심장에 피가 충분히 공급되지 않고 심근경색, 심부전 등 심장에 문제가 생길 수 있습니다.
# 심장 돌연사를 예측하기는 어렵지만 예방은 가능합니다.
# 금연과 절주, 적절한 운동은 필수고요.
# 무엇보다 급격한 온도 변화를 경계해야하는데요.
# 외출할 때는 마스크나 목도리 등으로 체온을 유지하고, 이른 아침이나 늦은 저녁 운동은 피하는 게 좋습니다.
# 또 전조 증상에도 주목할 필요가 있는데요.
# 묵직한 가슴 통증, 갑자기 가슴이 뛰고 숨이 찬 증상이 있으면 바로 병원을 찾아야합니다.
# 소리없는 살인자, 돌연사.
# 내 몸이 보내는 경고에 귀 기울이면 막을 수 있습니다.
#
# '길들이기'를 뜻하는 말,
# 그루밍.
# 흔히 동물이 털을 핥아 길들이는 행동을 지칭합니다.
# 그런데 성범죄와 관련되면 전혀 다른 뜻이 됩니다.
# 그루밍 성범죄.
# 어떤 의미일까요?
#
# 1. 그루밍
# '그루밍 성범죄'는 가해자가 피해자에게 호감을 얻거나 신뢰를 쌓은뒤 성적으로 착취하는 범죄를 의미합니다.
# 특히 어린이나 청소년 등 미성년자가 범죄의 대상이 되기 쉬운데요.
# 가해자는 피해자가 가해 행동을 자연스럽게 받아들이도록 길들이고, 나중에는 회유하거나 협박해 폭로를 막기도 합니다.
# 최근 '위계 또는 위력'을 이용해 13세 미만 아동 청소년을 대상으로 성범죄를 저지른 경우, 공소시효를 폐지하는 내용의 법 개정이 이뤄졌고요.
# 또 피해자가 13살이 넘는 청소년이라도 심리, 정신적으로 취약한 상황을 이용해 성관계를 맺은 경우 처벌할 수 있게 됐는데요.
# 신뢰를 악용한 그루밍 성범죄.
# 엄중한 가해자 처벌이 범죄를 막을 수 있는 해법 아닐까요?
#
# 지금까지 뉴스링크였습니다.

# %%
70
# Out:
# ['http://www.cstimes.com/', 'http://www.kyongbuk.co.kr/', 'http://www.geconomy.co.kr/', 'http://www.newsprime.co.kr/', 'http://www.mhns.co.kr/', 'http://www.headlinejeju.co.kr/', 'http://www.kihoilbo.co.kr/', 'http://www.kado.net/', 'http://www.kdfnews.com/', 'http://entertain.naver.com/', 'http://www.horsebiz.co.kr/', 'http://www.consumernews.co.kr/', 'https://www.asiatime.co.kr/', 'https://www.hidoc.co.kr/', 'http://www.gjdream.com/', 'http://ch1.skbroadband.comcontent/', 'http://digitalchosun.dizzo.com/', 'http://www.cctoday.co.kr/', 'https://www.ibabynews.com/', 'http://www.idomin.com/', 'https://www.fashionn.com/', 'https://www.etoday.co.kr/']
